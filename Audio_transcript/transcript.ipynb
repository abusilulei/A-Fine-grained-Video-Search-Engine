# %%
import pandas as pd
import os
import whisper
model = whisper.load_model("tiny")
# Out:
# /Users/ihhi/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class AudioObject:
    def __init__(self, audio_file_path):
        self.audio_file_path = audio_file_path
        self.audio = whisper.load_audio(audio_file_path)
        self.transcription = []

    def get_transcription(self):
        if self.transcription:
            print("Transcription already available")
            return self.transcription
        else:
            dict_temp = model.transcribe(self.audio)
            df_temp = pd.DataFrame(dict_temp['segments'])
            df_temp = df_temp[['start', 'end', 'text']]
            self.transcription = df_temp.to_dict('records')
            print("Transcription created")
            return self.transcription
    
    def write_file(self):
        name_temp = self.audio_file_path.split("/")[-1].split(".")[0]
        path_temp = "./output/" + name_temp + ".txt"
        # check whether the transcription is already available
        if self.transcription:
            # check if file exists
            if not os.path.exists(path_temp):
                with open(path_temp, 'w') as f:
                    for item in self.get_transcription():
                        f.write("%s\n" % item)
                print(f"File {name_temp}.txt created")
            else:
                print("File already exists")
        else:
            print("Transcription not available")
        return

# %%
test_audio = AudioObject("./audio/test0.mp3")

# %%
test_audio.get_transcription()
# Out:
# [{'start': 0.0, 'end': 2.0, 'text': '第一集'},
#  {'start': 2.0, 'end': 5.0, 'text': '遗到了这个小镇上'},
#  {'start': 5.0, 'end': 8.0, 'text': '第一眼看见长长的一排毛策'},
#  {'start': 8.0, 'end': 13.0, 'text': '都是迎面一个木板照闭 价在大石头上'},
#  {'start': 13.0, 'end': 17.0, 'text': '半周里面被对备的两个坑位'},
#  {'start': 17.0, 'end': 20.0, 'text': '接连不断的十几个小毛膨'},
#  {'start': 20.0, 'end': 22.0, 'text': '里面一个人也没有'},
#  {'start': 22.0, 'end': 27.0, 'text': '但是有时候一整封吹过来 微微发出臭气'},
#  {'start': 28.0, 'end': 33.0, 'text': '下午的阳光淡淡的晒在屋顶上白藏藏的毛草上'},
#  {'start': 34.0, 'end': 37.0, 'text': '走过这一排毛策就是电铺'},
#  {'start': 38.0, 'end': 43.0, 'text': '一排白色的小电 上面黑玉的处理着一座大山'},
#  {'start': 43.0, 'end': 48.0, 'text': '山头上又现出两抹淡清的远山'},
#  {'start': 48.0, 'end': 51.0, 'text': '急载的一条石子路'},
#  {'start': 51.0, 'end': 54.0, 'text': '对接连着一道碎石买墙'},
#  {'start': 54.0, 'end': 57.0, 'text': '强外忘出去什么也没有'},
#  {'start': 57.0, 'end': 61.0, 'text': '因为外面就是导得消落下去的微波'},
#  {'start': 61.0, 'end': 65.0, 'text': '这边一盘电里 走出一个女人'},
#  {'start': 65.0, 'end': 68.0, 'text': '捧着大红阳死脸盆过了街'},
#  {'start': 68.0, 'end': 72.0, 'text': '白一盆桑水 往海强外面移动'},
#  {'start': 72.0, 'end': 73.0, 'text': '不知为什么'},
#  {'start': 73.0, 'end': 76.0, 'text': '这几几几个东 有点是女人吃鸡'},
#  {'start': 76.0, 'end': 80.0, 'text': '像是白一盆烏水 漏出天涯海角'},
#  {'start': 80.0, 'end': 83.0, 'text': '世界的镜头'},
#  {'start': 83.0, 'end': 88.0, 'text': '差不多每一盘电里 都有一个沙气层层的老板娘做镇子'},
#  {'start': 88.0, 'end': 94.0, 'text': '人很受 一长焦黄的铃 头发直批下来'},
#  {'start': 94.0, 'end': 96.0, 'text': '垂到坚伤'},
#  {'start': 96.0, 'end': 99.0, 'text': '其没在这一顶 紛紫融蝦茂'},
#  {'start': 99.0, 'end': 104.0, 'text': '右二边 更坠着一颗孔确难大容坦'},
#  {'start': 104.0, 'end': 108.0, 'text': '也不知道是什么时候 新出来的这样的打扮'},
#  {'start': 108.0, 'end': 112.0, 'text': '到优点像细台上五生半的露灵打到'},
#  {'start': 112.0, 'end': 116.0, 'text': '时过往行人看了很感不安'},
#  {'start': 116.0, 'end': 122.0, 'text': '有一盆吃实店 卖的是小麻饼 与黑芝麻棒糖'},
#  {'start': 122.0, 'end': 128.0, 'text': '除了这两项之外 贵台上还对着两爹白芝小包'},
#  {'start': 128.0, 'end': 131.0, 'text': '看不出是什么一类的东西'},
#  {'start': 131.0, 'end': 135.0, 'text': '有人来买了一包 当场就拆开来吃'},
#  {'start': 135.0, 'end': 138.0, 'text': '原来里面包着五支小麻饼'},
#  {'start': 138.0, 'end': 143.0, 'text': '贵台上另外一辈纸包 相比是黑芝麻棒糖'},
#  {'start': 143.0, 'end': 147.0, 'text': '不过 也许人就是麻饼'},
#  {'start': 147.0, 'end': 153.0, 'text': '另一点贵台上 意到到的草植对击如生'},
#  {'start': 153.0, 'end': 156.0, 'text': '靠门确选空丁这个小玻璃厨'},
#  {'start': 156.0, 'end': 160.0, 'text': '里面沉烈着鸭糕鸭粉'},
#  {'start': 160.0, 'end': 163.0, 'text': '鸭粉的指贷与发家的纸板上'},
#  {'start': 163.0, 'end': 166.0, 'text': '都应有五彩明星照片'},
#  {'start': 167.0, 'end': 170.0, 'text': '鸭糕 中漫华 周玄'},
#  {'start': 170.0, 'end': 174.0, 'text': '一个个都对着那空的街道欠效着'},
#  {'start': 174.0, 'end': 179.0, 'text': '不知怎么 更增加了那荒良之感'},
#  {'start': 179.0, 'end': 182.0, 'text': '几只母机在街上走'},
#  {'start': 182.0, 'end': 186.0, 'text': '小心的直级一直脚来 小心的踩下去'},
#  {'start': 186.0, 'end': 191.0, 'text': '踏在那一刻刻 现在黑泥里的小原十字上'},
#  {'start': 191.0, 'end': 195.0, 'text': '东头来了个小饭 挑着蛋子'},
#  {'start': 195.0, 'end': 198.0, 'text': '卖的又是黑芝麻棒糖'},
#  {'start': 198.0, 'end': 201.0, 'text': '不论是香蕉是成理'},
#  {'start': 201.0, 'end': 204.0, 'text': '永远少不了有这么一香煮店'},
#  {'start': 204.0, 'end': 207.0, 'text': '坚满灯鲁 移粗粗的红辣煮'},
#  {'start': 207.0, 'end': 209.0, 'text': '高挂在物梁上'},
#  {'start': 209.0, 'end': 213.0, 'text': '向长行的红果子雷雷的垂下来'},
#  {'start': 213.0, 'end': 217.0, 'text': '隔壁的一店糖里四笔消忍'},
#  {'start': 217.0, 'end': 219.0, 'text': '只放着一张方桌'},
#  {'start': 219.0, 'end': 222.0, 'text': '一个小女孩坐在桌子跟前'},
#  {'start': 222.0, 'end': 225.0, 'text': '用机器拳土香煙'},
#  {'start': 225.0, 'end': 229.0, 'text': '那机器是个绿器的小羊铁盒子'},
#  {'start': 229.0, 'end': 231.0, 'text': '大概本来是一支羊油桶'},
#  {'start': 231.0, 'end': 235.0, 'text': '装了一支饼 或火油着'},
#  {'start': 235.0, 'end': 239.0, 'text': '太羊 像一支支狗 蓝街糖着'},
#  {'start': 239.0, 'end': 242.0, 'text': '太羊在这里老了'},
#  {'start': 242.0, 'end': 245.0, 'text': '路上来了个老太婆'},
#  {'start': 245.0, 'end': 248.0, 'text': '叫着那小饭问他芝麻糖的价钱'},
#  {'start': 249.0, 'end': 252.0, 'text': '他羊这里吃这眼 想他忘着'},
#  {'start': 252.0, 'end': 254.0, 'text': '忽然高兴地叫了起来'},
#  {'start': 254.0, 'end': 258.0, 'text': '这不是河生哥吗'},
#  {'start': 258.0, 'end': 261.0, 'text': '你们家两位老人家都好'},
#  {'start': 261.0, 'end': 265.0, 'text': '河生早好呀 你死身好'},
#  {'start': 265.0, 'end': 268.0, 'text': '那小饭起出正主了'},
#  {'start': 268.0, 'end': 270.0, 'text': '但随机想起来'},
#  {'start': 270.0, 'end': 272.0, 'text': '他是他死神的羊家亲戚'},
#  {'start': 272.0, 'end': 275.0, 'text': '房服曾经见过两面'},
#  {'start': 275.0, 'end': 279.0, 'text': '他各自生的爱 连行很短 超下吧'},
#  {'start': 279.0, 'end': 282.0, 'text': '连色赛成深者红'},
#  {'start': 282.0, 'end': 287.0, 'text': '想封干的山玉片羊 红而皱 香外捲着'},
#  {'start': 287.0, 'end': 290.0, 'text': '他带着舅士的肩口黑毛杂'},
#  {'start': 290.0, 'end': 293.0, 'text': '穿着补了又补的蓝布大'},
#  {'start': 293.0, 'end': 295.0, 'text': '他总是逼逼着眼睛'},
#  {'start': 295.0, 'end': 298.0, 'text': '房服太羊正照在连上'},
#  {'start': 298.0, 'end': 301.0, 'text': '说话总是高深寒叫着'},
#  {'start': 301.0, 'end': 305.0, 'text': '房服中间隔着大片的甜蜻'},
#  {'start': 305.0, 'end': 309.0, 'text': '你这位大神 难得到正上来的吧'},
#  {'start': 309.0, 'end': 311.0, 'text': '这小饭问他'},
#  {'start': 311.0, 'end': 315.0, 'text': '我今天是陪我知女儿来的'},
#  {'start': 315.0, 'end': 318.0, 'text': '老夫人大生喊着'},
#  {'start': 318.0, 'end': 322.0, 'text': '知女明天出价 嫁到周村'},
#  {'start': 322.0, 'end': 324.0, 'text': '今天到区上去登记'},
#  {'start': 324.0, 'end': 328.0, 'text': '那孩子可恋 爹娘都没有了'},
#  {'start': 328.0, 'end': 330.0, 'text': '我一个哥哥'},
#  {'start': 330.0, 'end': 334.0, 'text': '嫂嫂呢 又上城去帮人家去了'},
#  {'start': 334.0, 'end': 336.0, 'text': '家里就是一个哥哥'},
#  {'start': 336.0, 'end': 340.0, 'text': '他们周家人多 今天他们都要到的'},
#  {'start': 340.0, 'end': 343.0, 'text': '我们这边人太少了不像样'},
#  {'start': 343.0, 'end': 345.0, 'text': '我知后也跟了来了'},
#  {'start': 345.0, 'end': 349.0, 'text': '他养着连去这眼 忘着他笑'},
#  {'start': 349.0, 'end': 352.0, 'text': '也真是巧'},
#  {'start': 352.0, 'end': 354.0, 'text': '怎么会碰见你的'},
#  {'start': 355.0, 'end': 358.0, 'text': '我们刚来正在那边路停里些酒'},
#  {'start': 358.0, 'end': 360.0, 'text': '我对他们说'},
#  {'start': 360.0, 'end': 363.0, 'text': '我说你们现在这做一会儿'},
#  {'start': 363.0, 'end': 367.0, 'text': '我去瞧瞧看他们周家的人来了没有'},
#  {'start': 367.0, 'end': 370.0, 'text': '不要我们比他们先到'},
#  {'start': 370.0, 'end': 373.0, 'text': '显得心羊子太幸急了不好'},
#  {'start': 373.0, 'end': 376.0, 'text': '好 心郎来了没有'},
#  {'start': 376.0, 'end': 378.0, 'text': '来了来了'},
#  {'start': 378.0, 'end': 381.0, 'text': '我瞅见几个周家的人'},
#  {'start': 381.0, 'end': 383.0, 'text': '坐在区工所的台街上'},
#  {'start': 383.0, 'end': 388.0, 'text': '我得要走了去把心羊子领来'},
#  {'start': 388.0, 'end': 391.0, 'text': '让人家老等着也不好'},
#  {'start': 391.0, 'end': 394.0, 'text': '你也不要老站在这里说话'},
#  {'start': 394.0, 'end': 396.0, 'text': '单个了生意'},
#  {'start': 396.0, 'end': 398.0, 'text': '生意好吧'},
#  {'start': 398.0, 'end': 402.0, 'text': '你刚才说这堂多少钱已经'},
#  {'start': 402.0, 'end': 406.0, 'text': '这小饭这次就不肯告诉他嫁亲了'},
#  {'start': 406.0, 'end': 408.0, 'text': '他万一要减起两根棒堂'},
#  {'start': 408.0, 'end': 410.0, 'text': '应该在他手里'},
#  {'start': 411.0, 'end': 413.0, 'text': '大神 这个你拿去吃'},
#  {'start': 413.0, 'end': 415.0, 'text': '常常还不换'},
#  {'start': 415.0, 'end': 418.0, 'text': '他胡气脸推开了他的手'},
#  {'start': 418.0, 'end': 420.0, 'text': '有不行不行'},
#  {'start': 420.0, 'end': 422.0, 'text': '没这个道理'},
#  {'start': 422.0, 'end': 424.0, 'text': '这些年没见面'},
#  {'start': 424.0, 'end': 427.0, 'text': '哪有一见面就拿人家的东西'},
#  {'start': 427.0, 'end': 431.0, 'text': '你拿着拿着拿回去给小孩子吃'},
#  {'start': 431.0, 'end': 434.0, 'text': '这倒是想买点'},
#  {'start': 434.0, 'end': 436.0, 'text': '回去红红孩子们'},
#  {'start': 436.0, 'end': 438.0, 'text': '不能叫你送'},
#  {'start': 438.0, 'end': 441.0, 'text': '没有我自己是吃不动他了'},
#  {'start': 441.0, 'end': 445.0, 'text': '老了 牙齿一直都没有了'},
#  {'start': 445.0, 'end': 448.0, 'text': '两人推来让去好一坏'},
#  {'start': 448.0, 'end': 452.0, 'text': '那两根量赢的白花点子小黑棒'},
#  {'start': 452.0, 'end': 453.0, 'text': '见见融化了'},
#  {'start': 453.0, 'end': 455.0, 'text': '您在小饭手上'},
#  {'start': 455.0, 'end': 457.0, 'text': '他虽然面带笑容'},
#  {'start': 457.0, 'end': 460.0, 'text': '脸上见见饭出红色'},
#  {'start': 460.0, 'end': 462.0, 'text': '有点不耐煩的样子'},
#  {'start': 462.0, 'end': 464.0, 'text': '最近纯蛇'},
#  {'start': 464.0, 'end': 467.0, 'text': '那老太太终于迷强接受了'},
#  {'start': 467.0, 'end': 470.0, 'text': '蛮强尾虚地词别了他'},
#  {'start': 470.0, 'end': 472.0, 'text': '盘山的走开去'},
#  {'start': 472.0, 'end': 474.0, 'text': '他这一准备'},
#  {'start': 474.0, 'end': 476.0, 'text': '小饭脸上的笑容'},
#  {'start': 476.0, 'end': 478.0, 'text': '本是一准地盘'},
#  {'start': 478.0, 'end': 480.0, 'text': '再老太婆的脸上出现'},
#  {'start': 480.0, 'end': 483.0, 'text': '他板着脸跳着蛋子走了'},
#  {'start': 483.0, 'end': 485.0, 'text': '他确实笑音音的'},
#  {'start': 485.0, 'end': 487.0, 'text': '小小异管异管的'},
#  {'start': 487.0, 'end': 490.0, 'text': '走过那一排店铺与毛侧'},
#  {'start': 490.0, 'end': 491.0, 'text': '出了事正'},
#  {'start': 491.0, 'end': 493.0, 'text': '向官堂大陆上'},
#  {'start': 493.0, 'end': 496.0, 'text': '那座白粉强的停子走去'},
#  {'start': 497.0, 'end': 499.0, 'text': '碰见一个人'},
#  {'start': 499.0, 'end': 501.0, 'text': '他老元就喊着'},
#  {'start': 501.0, 'end': 504.0, 'text': '又再也想不到的'},
#  {'start': 504.0, 'end': 507.0, 'text': '我不是有个表妹嫁到淘西'},
#  {'start': 507.0, 'end': 510.0, 'text': '这就是他婆家的植子'},
#  {'start': 510.0, 'end': 513.0, 'text': '我看着他好像眼熟'},
#  {'start': 513.0, 'end': 517.0, 'text': '这些年不见都不敢喊出口来'},
#  {'start': 518.0, 'end': 522.0, 'text': '他植子心跟听得有点不耐煩起来了'},
#  {'start': 522.0, 'end': 524.0, 'text': '他们来了没有周家的人'},
#  {'start': 525.0, 'end': 526.0, 'text': '他问'},
#  {'start': 526.0, 'end': 529.0, 'text': '他站在路停的窮门下等着他'},
#  {'start': 529.0, 'end': 531.0, 'text': '是个高大的年轻人'},
#  {'start': 531.0, 'end': 533.0, 'text': '面貌很均熟'},
#  {'start': 533.0, 'end': 536.0, 'text': '皮膚是暗淡的你土的颜色'},
#  {'start': 536.0, 'end': 537.0, 'text': '宽间堡'},
#  {'start': 537.0, 'end': 540.0, 'text': '隔着一层棉老都看得见'},
#  {'start': 540.0, 'end': 543.0, 'text': '就棉老越穿越薄'},
#  {'start': 543.0, 'end': 545.0, 'text': '而且洗腿了四'},
#  {'start': 545.0, 'end': 547.0, 'text': '腿成极淡的蓝'},
#  {'start': 547.0, 'end': 548.0, 'text': '来了'},
#  {'start': 548.0, 'end': 550.0, 'text': '我看见他们来的'},
#  {'start': 550.0, 'end': 551.0, 'text': '来了'},
#  {'start': 551.0, 'end': 553.0, 'text': '那我们去吧'},
#  {'start': 554.0, 'end': 555.0, 'text': '金根回过头'},
#  {'start': 555.0, 'end': 557.0, 'text': '向他妹妹说'},
#  {'start': 557.0, 'end': 558.0, 'text': '他妹子精花'},
#  {'start': 558.0, 'end': 560.0, 'text': '向梅听见死的'},
#  {'start': 560.0, 'end': 563.0, 'text': '他坐在停子里被对着他'},
#  {'start': 563.0, 'end': 565.0, 'text': '正在土透摩在手镜子上'},
#  {'start': 565.0, 'end': 568.0, 'text': '听那小女孩擦手'},
#  {'start': 568.0, 'end': 570.0, 'text': '小女孩是金根的女儿'},
#  {'start': 570.0, 'end': 573.0, 'text': '他们今天把他也带了来了'},
#  {'start': 573.0, 'end': 576.0, 'text': '那孩子正在那闹变你'},
#  {'start': 576.0, 'end': 577.0, 'text': '因为他不明白'},
#  {'start': 577.0, 'end': 580.0, 'text': '为什么要在这里等着'},
#  {'start': 580.0, 'end': 582.0, 'text': '他反造的在板等上'},
#  {'start': 582.0, 'end': 584.0, 'text': '爬上爬下'},
#  {'start': 584.0, 'end': 587.0, 'text': '又深守去摸那善行的窗户'},
#  {'start': 587.0, 'end': 590.0, 'text': '把两支手摸的污黑'},
#  {'start': 590.0, 'end': 591.0, 'text': '不久'},
#  {'start': 591.0, 'end': 593.0, 'text': '他一定会把那些灰'},
#  {'start': 593.0, 'end': 596.0, 'text': '都摸到他估过的心意伏上去'},
#  {'start': 596.0, 'end': 597.0, 'text': '金花'},
#  {'start': 597.0, 'end': 600.0, 'text': '今天穿着三件子红布棉膨'},
#  {'start': 600.0, 'end': 603.0, 'text': '也就是明天的结婚礼服'},
#  {'start': 603.0, 'end': 606.0, 'text': '金根看得妹妹不打化'},
#  {'start': 606.0, 'end': 608.0, 'text': '他站在那里插着腰望着他'},
#  {'start': 608.0, 'end': 611.0, 'text': '透出没有办法的样子'},
#  {'start': 611.0, 'end': 614.0, 'text': '老夫人传着气走进路廷'},
#  {'start': 614.0, 'end': 616.0, 'text': '怎么不去啊'},
#  {'start': 616.0, 'end': 619.0, 'text': '他大生喊着'},
#  {'start': 619.0, 'end': 620.0, 'text': '走吧'},
#  {'start': 620.0, 'end': 621.0, 'text': '我们走吧'},
#  {'start': 621.0, 'end': 623.0, 'text': '金根对他妹妹说'},
#  {'start': 623.0, 'end': 625.0, 'text': '别这么老脑禁'},
#  {'start': 626.0, 'end': 627.0, 'text': '谁老脑禁'},
#  {'start': 627.0, 'end': 630.0, 'text': '他并没有回过头来'},
#  {'start': 630.0, 'end': 633.0, 'text': '也得让大娘坐下来些火'},
#  {'start': 633.0, 'end': 634.0, 'text': '传过这口气来'},
#  {'start': 634.0, 'end': 636.0, 'text': '才走来又走去'},
#  {'start': 636.0, 'end': 637.0, 'text': '人家不累吗'},
#  {'start': 638.0, 'end': 640.0, 'text': '走吧走吧'},
#  {'start': 641.0, 'end': 642.0, 'text': '别害怕了'},
#  {'start': 642.0, 'end': 644.0, 'text': '现在这实事'},
#  {'start': 644.0, 'end': 645.0, 'text': '不行害怕了'},
#  {'start': 646.0, 'end': 647.0, 'text': '谁害怕'},
#  {'start': 648.0, 'end': 649.0, 'text': '金花堵气站起来'},
#  {'start': 649.0, 'end': 651.0, 'text': '领着头走到正上去'},
#  {'start': 652.0, 'end': 653.0, 'text': '他今年18岁'},
#  {'start': 654.0, 'end': 655.0, 'text': '可是看上去'},
#  {'start': 655.0, 'end': 656.0, 'text': '还不到正年级'},
#  {'start': 657.0, 'end': 659.0, 'text': '至期的秀利的脸'},
#  {'start': 659.0, 'end': 661.0, 'text': '嘴臣威威张开着'},
#  {'start': 661.0, 'end': 664.0, 'text': '因为前面有一支鸭月有点暴'},
#  {'start': 665.0, 'end': 667.0, 'text': '他的头发前面疼得高高的'},
#  {'start': 667.0, 'end': 671.0, 'text': '额上一排大西书的前流海'},
#  {'start': 671.0, 'end': 672.0, 'text': '流的很长'},
#  {'start': 672.0, 'end': 674.0, 'text': '直垂到眼睛里去'},
#  {'start': 674.0, 'end': 676.0, 'text': '养缩缩的'},
#  {'start': 676.0, 'end': 678.0, 'text': '所以他总是逼着眼睛'},
#  {'start': 678.0, 'end': 681.0, 'text': '从法思里相外面忘着'},
#  {'start': 681.0, 'end': 684.0, 'text': '防夫带着点焦慮的神奇'},
#  {'start': 684.0, 'end': 686.0, 'text': '这小小的航力'},
#  {'start': 686.0, 'end': 688.0, 'text': '他走在最前面'},
#  {'start': 688.0, 'end': 690.0, 'text': '老夫人在后面紧紧跟着'},
#  {'start': 690.0, 'end': 692.0, 'text': '就像是怕他'},
#  {'start': 692.0, 'end': 694.0, 'text': '随时会转过身来逃走'},
#  {'start': 695.0, 'end': 697.0, 'text': '亲跟抱着他的女儿'},
#  {'start': 697.0, 'end': 698.0, 'text': '跟在他们后面'},
#  {'start': 699.0, 'end': 701.0, 'text': '快到去工作的时候'},
#  {'start': 701.0, 'end': 703.0, 'text': '老夫人就本能的走进一步'},
#  {'start': 703.0, 'end': 705.0, 'text': '脱住精花的着弯'},
#  {'start': 705.0, 'end': 706.0, 'text': '碗着他走'},
#  {'start': 707.0, 'end': 708.0, 'text': '但呀'},
#  {'start': 708.0, 'end': 709.0, 'text': '别这么风见'},
#  {'start': 709.0, 'end': 710.0, 'text': '他自己会走'},
#  {'start': 711.0, 'end': 712.0, 'text': '亲跟说'},
#  {'start': 713.0, 'end': 715.0, 'text': '去工作前面'},
#  {'start': 715.0, 'end': 717.0, 'text': '坐着蹲着的人群中'},
#  {'start': 717.0, 'end': 718.0, 'text': '起来一陈儿骚动'},
#  {'start': 719.0, 'end': 720.0, 'text': '他们来了'},
#  {'start': 720.0, 'end': 721.0, 'text': '新娘子来了'},
#  {'start': 721.0, 'end': 723.0, 'text': '大家难难说着'},
#  {'start': 724.0, 'end': 726.0, 'text': '有几个周家的人走上来'},
#  {'start': 726.0, 'end': 728.0, 'text': '含笑和金跟招呼'},
#  {'start': 728.0, 'end': 731.0, 'text': '有个武是来碎的高高的夫人'},
#  {'start': 731.0, 'end': 732.0, 'text': '一连精明的样子'},
#  {'start': 732.0, 'end': 735.0, 'text': '是新郎的馆父母亲'},
#  {'start': 735.0, 'end': 737.0, 'text': '朝着谈大娘走过来'},
#  {'start': 737.0, 'end': 739.0, 'text': '抓住他两只手说'},
#  {'start': 739.0, 'end': 741.0, 'text': '哎呀'},
#  {'start': 741.0, 'end': 742.0, 'text': '大远的路'},
#  {'start': 742.0, 'end': 744.0, 'text': '让你走了这么一趟'},
#  {'start': 744.0, 'end': 745.0, 'text': '趁不过一'},
#  {'start': 746.0, 'end': 748.0, 'text': '明天要做新郎的男孩子'},
#  {'start': 748.0, 'end': 750.0, 'text': '站得远远的微笑着'},
#  {'start': 750.0, 'end': 753.0, 'text': '谁也不朝新娘子看'},
#  {'start': 753.0, 'end': 754.0, 'text': '但当人'},
#  {'start': 754.0, 'end': 756.0, 'text': '他还是被观察着的'},
#  {'start': 757.0, 'end': 759.0, 'text': '他也微带着笑容'},
#  {'start': 759.0, 'end': 761.0, 'text': '而仿佛心不在因死的'},
#  {'start': 761.0, 'end': 763.0, 'text': '漫无目地思面望着'},
#  {'start': 765.0, 'end': 766.0, 'text': '大家招呼过来'},
#  {'start': 766.0, 'end': 767.0, 'text': '就一同进去'},
#  {'start': 768.0, 'end': 770.0, 'text': '先经过一番低生争论'},
#  {'start': 770.0, 'end': 772.0, 'text': '要推出一个人来'},
#  {'start': 772.0, 'end': 774.0, 'text': '出面和干不说话'},
#  {'start': 775.0, 'end': 777.0, 'text': '当然应当由男方上前'},
#  {'start': 778.0, 'end': 780.0, 'text': '而且刚巧新郎的母亲'},
#  {'start': 780.0, 'end': 782.0, 'text': '在一切有官方面'},
#  {'start': 782.0, 'end': 783.0, 'text': '是他最年长'},
#  {'start': 784.0, 'end': 785.0, 'text': '但是他坚持着'},
#  {'start': 785.0, 'end': 787.0, 'text': '这不是女人做的事'},
#  {'start': 787.0, 'end': 789.0, 'text': '要经根去'},
#  {'start': 789.0, 'end': 791.0, 'text': '经根一定不肯'},
#  {'start': 792.0, 'end': 793.0, 'text': '最后是新郎的大哥'},
#  {'start': 793.0, 'end': 794.0, 'text': '做了代言人'},
#  {'start': 796.0, 'end': 798.0, 'text': '和干不说明来以之后'},
#  {'start': 798.0, 'end': 800.0, 'text': '大家都记在桌子前面'},
#  {'start': 800.0, 'end': 803.0, 'text': '等着干不找出该甜的表格'},
#  {'start': 804.0, 'end': 806.0, 'text': '新郎心良被推到最前方'},
#  {'start': 807.0, 'end': 810.0, 'text': '低着头站在桌子跟前'},
#  {'start': 810.0, 'end': 812.0, 'text': '你名字笑什么'},
#  {'start': 812.0, 'end': 814.0, 'text': '干不问的年轻人'},
#  {'start': 815.0, 'end': 817.0, 'text': '周大有'},
#  {'start': 817.0, 'end': 819.0, 'text': '是哪里人'},
#  {'start': 819.0, 'end': 820.0, 'text': '周村的人'},
#  {'start': 821.0, 'end': 822.0, 'text': '也要跟谁结婚'},
#  {'start': 823.0, 'end': 825.0, 'text': '他很快地辜入了一生'},
#  {'start': 825.0, 'end': 826.0, 'text': '谈精华'},
#  {'start': 827.0, 'end': 828.0, 'text': '因为他能劳动'},
#  {'start': 829.0, 'end': 832.0, 'text': '精华也回答了同样的问质'},
#  {'start': 832.0, 'end': 835.0, 'text': '问到为什么要跟他结婚'},
#  {'start': 835.0, 'end': 837.0, 'text': '他也照别人预线交的那样'},
#  {'start': 837.0, 'end': 839.0, 'text': '难难念着标准答案'},
#  {'start': 840.0, 'end': 841.0, 'text': '因为他能劳动'},
#  {'start': 842.0, 'end': 845.0, 'text': '任何别的回答都会引起更多的问质'},
#  {'start': 846.0, 'end': 848.0, 'text': '或是会引起麻烦'},
#  {'start': 849.0, 'end': 852.0, 'text': '新郎心良在表格下面那的指应'},
#  {'start': 853.0, 'end': 856.0, 'text': '他们的婚姻在法律上已经成立了'},
#  {'start': 857.0, 'end': 858.0, 'text': '但是习俗相言'},
#  {'start': 859.0, 'end': 860.0, 'text': '明日还要热脑下'},
#  {'start': 861.0, 'end': 862.0, 'text': '暂时'},
#  {'start': 862.0, 'end': 864.0, 'text': '新郎还是跟着娘家人'},
#  {'start': 864.0, 'end': 865.0, 'text': '一同回去'},
#  {'start': 866.0, 'end': 869.0, 'text': '周家和谈家的人在去公司外面分了手'},
#  {'start': 870.0, 'end': 872.0, 'text': '明天早点来啊'},
#  {'start': 872.0, 'end': 873.0, 'text': '谈大娘'},
#  {'start': 873.0, 'end': 875.0, 'text': '新郎的母亲在三所'},
#  {'start': 876.0, 'end': 879.0, 'text': '你今天早点回去谢谢吧'},
#  {'start': 879.0, 'end': 881.0, 'text': '明天有你忙的'},
#  {'start': 882.0, 'end': 885.0, 'text': '谈家几个人在小镇上还缓走镇'},
#  {'start': 886.0, 'end': 887.0, 'text': '一路看热闹'},
#  {'start': 888.0, 'end': 889.0, 'text': '精华进进的'},
#  {'start': 890.0, 'end': 891.0, 'text': '一句话也不说'},
#  {'start': 892.0, 'end': 894.0, 'text': '手里牵着那小女孩'},
#  {'start': 895.0, 'end': 897.0, 'text': '他们走过镇上唯一的犯管子'},
#  {'start': 898.0, 'end': 900.0, 'text': '是一座木板大的房屋'},
#  {'start': 901.0, 'end': 902.0, 'text': '那么游气过了木板'},
#  {'start': 903.0, 'end': 904.0, 'text': '是一条条不均匀的'},
#  {'start': 905.0, 'end': 906.0, 'text': '先名的城黄色'},
#  {'start': 907.0, 'end': 908.0, 'text': '门面很高大'},
#  {'start': 909.0, 'end': 910.0, 'text': '前面完全尝着'},
#  {'start': 911.0, 'end': 912.0, 'text': '望近去'},
#  {'start': 912.0, 'end': 914.0, 'text': '里面黑胡胡闹哄哄的'},
#  {'start': 916.0, 'end': 917.0, 'text': '房顶上'},
#  {'start': 918.0, 'end': 919.0, 'text': '到处有各种石料'},
#  {'start': 919.0, 'end': 920.0, 'text': '里里的掛下来'},
#  {'start': 921.0, 'end': 922.0, 'text': '一刻刻白菜'},
#  {'start': 923.0, 'end': 924.0, 'text': '灰铺铺的火腿'},
#  {'start': 925.0, 'end': 926.0, 'text': '长条的线肉'},
#  {'start': 927.0, 'end': 928.0, 'text': '主白的脆的豆腐皮'},
#  {'start': 929.0, 'end': 931.0, 'text': '与蛋黄色半透明的起泡的鱼堵'},
#  {'start': 932.0, 'end': 933.0, 'text': '都掛在客人头上'},
#  {'start': 935.0, 'end': 936.0, 'text': '跑糖的同时也上噪'},
#  {'start': 937.0, 'end': 938.0, 'text': '在大门口沙沙的炒菜'},
#  {'start': 939.0, 'end': 940.0, 'text': '用花张的大动作'},
#  {'start': 941.0, 'end': 942.0, 'text': '抓把盐 撒点葱花'},
#  {'start': 943.0, 'end': 945.0, 'text': '然后从林之锅里'},
#  {'start': 946.0, 'end': 947.0, 'text': '水灵灵的捞出一团面汤'},
#  {'start': 947.0, 'end': 950.0, 'text': '撒一声 头到油锅里'},
#  {'start': 951.0, 'end': 953.0, 'text': '月发油 飞沙走石之事'},
#  {'start': 954.0, 'end': 956.0, 'text': '门外有个小姑娘'},
#  {'start': 957.0, 'end': 958.0, 'text': '蹲在街沿上'},
#  {'start': 959.0, 'end': 960.0, 'text': '穿着油拆绿的库子'},
#  {'start': 960.0, 'end': 961.0, 'text': '向白泥造里天才'},
#  {'start': 962.0, 'end': 963.0, 'text': '饭店里'},
#  {'start': 964.0, 'end': 966.0, 'text': '流泥的热闹都满意到街上来了'},
#  {'start': 968.0, 'end': 970.0, 'text': '金根的小女儿站在饭店门口'},
#  {'start': 971.0, 'end': 972.0, 'text': '不肯走'},
#  {'start': 973.0, 'end': 974.0, 'text': '金花饮拉他走'},
#  {'start': 974.0, 'end': 977.0, 'text': '起来拼命向后增炸 赖在地下'},
#  {'start': 978.0, 'end': 980.0, 'text': '油不要哭 不要哭'},
#  {'start': 981.0, 'end': 982.0, 'text': '老夫人说'},
#  {'start': 983.0, 'end': 985.0, 'text': '明天就好东西吃了'},
#  {'start': 986.0, 'end': 987.0, 'text': '明天你哭不出价'},
#  {'start': 988.0, 'end': 989.0, 'text': '我们都去吃洗酒'},
#  {'start': 990.0, 'end': 992.0, 'text': '要吃鱼 又吃肉'},
#  {'start': 993.0, 'end': 996.0, 'text': '你在哭 你在哭明天不带你吃了'},
#  {'start': 997.0, 'end': 1000.0, 'text': '但是连这个也下呼不住他'},
#  {'start': 1001.0, 'end': 1003.0, 'text': '孩子闹的是大家非常久'},
#  {'start': 1004.0, 'end': 1007.0, 'text': '饭店的火劲站在早前向他们看着'},
#  {'start': 1008.0, 'end': 1010.0, 'text': '那端在外面天茶的女孩子'},
#  {'start': 1010.0, 'end': 1012.0, 'text': '也别过头来看他们'},
#  {'start': 1013.0, 'end': 1015.0, 'text': '金根挽下腰区'},
#  {'start': 1015.0, 'end': 1016.0, 'text': '把孩子一把抱起来'},
#  {'start': 1017.0, 'end': 1019.0, 'text': '不管他怎样增炸着乱踢着'},
#  {'start': 1020.0, 'end': 1022.0, 'text': '他很快地走出了市场'},
#  {'start': 1023.0, 'end': 1024.0, 'text': '孩子哭得一抽一抽的'},
#  {'start': 1026.0, 'end': 1027.0, 'text': '不要哭'},
#  {'start': 1028.0, 'end': 1029.0, 'text': '他揉声说'},
#  {'start': 1029.0, 'end': 1030.0, 'text': '你妈就要回来了'},
#  {'start': 1031.0, 'end': 1032.0, 'text': '他带好东西来给你吃'},
#  {'start': 1033.0, 'end': 1034.0, 'text': '你还记得妈妈'},
#  {'start': 1035.0, 'end': 1037.0, 'text': '孩子的妈在上海帮拥'},
#  {'start': 1038.0, 'end': 1040.0, 'text': '他几个月前就写了信回来'},
#  {'start': 1041.0, 'end': 1043.0, 'text': '说他要辞工回来重填'},
#  {'start': 1044.0, 'end': 1046.0, 'text': '金根现在分到了填了'},
#  {'start': 1047.0, 'end': 1048.0, 'text': '自从土改以后'},
#  {'start': 1049.0, 'end': 1051.0, 'text': '但是家里仍舊很苦'},
#  {'start': 1052.0, 'end': 1054.0, 'text': '全靠他在外面既钱回来'},
#  {'start': 1055.0, 'end': 1057.0, 'text': '所以他一直言来着没有辞工'},
#  {'start': 1059.0, 'end': 1061.0, 'text': '金根现在对孩子说是这样说'},
#  {'start': 1062.0, 'end': 1064.0, 'text': '其实他心里估执'},
#  {'start': 1064.0, 'end': 1067.0, 'text': '他估计不见得能回了过年'},
#  {'start': 1069.0, 'end': 1071.0, 'text': '他们这孩子叫阿州'},
#  {'start': 1072.0, 'end': 1074.0, 'text': '无非是希望他会招来一个弟弟'},
#  {'start': 1075.0, 'end': 1078.0, 'text': '但是这几年他母亲一直不在家鄉'},
#  {'start': 1079.0, 'end': 1082.0, 'text': '所以阿州一直是白白的招着手'},
#  {'start': 1083.0, 'end': 1085.0, 'text': '不要哭阿州'},
#  {'start': 1086.0, 'end': 1087.0, 'text': '金根男男的说着'},
#  {'start': 1088.0, 'end': 1089.0, 'text': '妈妈就要回来了'},
#  {'start': 1090.0, 'end': 1091.0, 'text': '带好东西来给你吃'},
#  {'start': 1093.0, 'end': 1095.0, 'text': '这话似乎并没有发生笑容'},
#  {'start': 1096.0, 'end': 1099.0, 'text': '但是那天晚上他听见他问金花'},
#  {'start': 1100.0, 'end': 1102.0, 'text': '姑姑妈什么时候回来'},
#  {'start': 1103.0, 'end': 1105.0, 'text': '爸说妈就要回来了'},
#  {'start': 1107.0, 'end': 1108.0, 'text': '他连红的非常厉害'},
#  {'start': 1109.0, 'end': 1112.0, 'text': '因为被人发现他在那里想念他期'},
#  {'start': 1113.0, 'end': 1115.0, 'text': '分明是叛亡他回家'},
#  {'start': 1116.0, 'end': 1119.0, 'text': '这是晚饭后他正站在门口西汉烟'},
#  {'start': 1120.0, 'end': 1121.0, 'text': '被对着房礼'},
#  {'start': 1122.0, 'end': 1124.0, 'text': '然后他听见他妹妹回答'},
#  {'start': 1126.0, 'end': 1128.0, 'text': '是啊妈就要回来了'},
#  {'start': 1129.0, 'end': 1131.0, 'text': '你有妈不会想我了'},
#  {'start': 1132.0, 'end': 1134.0, 'text': '他的声音听上去是微笑的'},
#  {'start': 1135.0, 'end': 1137.0, 'text': '但似乎有点被爱'},
#  {'start': 1139.0, 'end': 1142.0, 'text': '他上床以后看见他妹妹房里还点着灯'},
#  {'start': 1143.0, 'end': 1145.0, 'text': '早点睡吧 金花妹'},
#  {'start': 1146.0, 'end': 1147.0, 'text': '他高声喊着'},
#  {'start': 1148.0, 'end': 1149.0, 'text': '明天你还要走失礼入呢'},
#  {'start': 1150.0, 'end': 1151.0, 'text': '你还没睡啊'},
#  {'start': 1152.0, 'end': 1153.0, 'text': '你来回要走二十里呢'},
#  {'start': 1155.0, 'end': 1156.0, 'text': '灯仍就点着'},
#  {'start': 1157.0, 'end': 1159.0, 'text': '他听见他在房间里走来走去'},
#  {'start': 1160.0, 'end': 1161.0, 'text': '不知道在忙些什么'},
#  {'start': 1162.0, 'end': 1164.0, 'text': '他心里充满了仇唱'},
#  {'start': 1167.0, 'end': 1168.0, 'text': '在早晨'},
#  {'start': 1169.0, 'end': 1171.0, 'text': '村里的人都几在他家门口看心娘子'},
#  {'start': 1172.0, 'end': 1174.0, 'text': '金花装办好了坐在哪里'},
#  {'start': 1175.0, 'end': 1177.0, 'text': '有一个挑选出的全服太阪'},
#  {'start': 1177.0, 'end': 1179.0, 'text': '在旁边替他书头'},
#  {'start': 1180.0, 'end': 1181.0, 'text': '擦粉抹腌纸'},
#  {'start': 1182.0, 'end': 1184.0, 'text': '其实现在头发简短了'},
#  {'start': 1185.0, 'end': 1186.0, 'text': '根本不用怎么书'},
#  {'start': 1187.0, 'end': 1189.0, 'text': '他自己也已经抹过腌纸粉了'},
#  {'start': 1190.0, 'end': 1191.0, 'text': '这不过是讨个吉利'},
#  {'start': 1192.0, 'end': 1195.0, 'text': '希望新娘子将来也和他一样福气'},
#  {'start': 1197.0, 'end': 1198.0, 'text': '弹大娘是不合格的'},
#  {'start': 1199.0, 'end': 1201.0, 'text': '他虽然福气白头写了'},
#  {'start': 1202.0, 'end': 1204.0, 'text': '只有一个儿子人拉夫拉走了'},
#  {'start': 1205.0, 'end': 1208.0, 'text': '这许多年来一直陰性全无'},
#  {'start': 1209.0, 'end': 1210.0, 'text': '实际上到了'},
#  {'start': 1211.0, 'end': 1212.0, 'text': '新娘就动身'},
#  {'start': 1213.0, 'end': 1214.0, 'text': '走到十里外的周村'},
#  {'start': 1215.0, 'end': 1218.0, 'text': '一个堂房兄弟走到他面前打着楼'},
#  {'start': 1219.0, 'end': 1220.0, 'text': '送亲的金根'},
#  {'start': 1221.0, 'end': 1223.0, 'text': '抱着阿招跟在他后面提着展登楼'},
#  {'start': 1224.0, 'end': 1225.0, 'text': '因为今天要深夜回来'},
#  {'start': 1227.0, 'end': 1228.0, 'text': '他两只手都站住了'},
#  {'start': 1229.0, 'end': 1231.0, 'text': '所以新娘自己提着包袱'},
#  {'start': 1232.0, 'end': 1235.0, 'text': '他穿着后蹲蹲的新棉毛'},
#  {'start': 1236.0, 'end': 1237.0, 'text': '身上远滚滚的'},
#  {'start': 1238.0, 'end': 1240.0, 'text': '凶前配着一朵大红军花'},
#  {'start': 1241.0, 'end': 1243.0, 'text': '和老洞英雄们带的一样'},
#  {'start': 1244.0, 'end': 1246.0, 'text': '新餐军的人在会场里坐在台上'},
#  {'start': 1247.0, 'end': 1248.0, 'text': '也是带着这样的话'},
#  {'start': 1250.0, 'end': 1252.0, 'text': '那小小的航列穿过村庄'},
#  {'start': 1253.0, 'end': 1254.0, 'text': '大罗一生生敲着'},
#  {'start': 1255.0, 'end': 1257.0, 'text': '到处都有父女与小孩坚生教着'},
#  {'start': 1258.0, 'end': 1259.0, 'text': '来看新娘子'},
#  {'start': 1259.0, 'end': 1262.0, 'text': '一大群人只送到村口'},
#  {'start': 1263.0, 'end': 1265.0, 'text': '谈大娘站在最前面'},
#  {'start': 1266.0, 'end': 1268.0, 'text': '高生念送着吉利化'},
#  {'start': 1269.0, 'end': 1270.0, 'text': '他等一会儿也要去的'},
#  {'start': 1271.0, 'end': 1274.0, 'text': '和他丈夫一同去吃洗酒'},
#  {'start': 1275.0, 'end': 1277.0, 'text': '老头子呢'},
#  {'start': 1278.0, 'end': 1280.0, 'text': '他回过头去四面张望着'},
#  {'start': 1281.0, 'end': 1282.0, 'text': '跑哪去了'},
#  {'start': 1283.0, 'end': 1285.0, 'text': '他没敢上看见新娘子动身'},
#  {'start': 1285.0, 'end': 1288.0, 'text': '老头子坐在大陆边'},
#  {'start': 1289.0, 'end': 1291.0, 'text': '一个小小的路天毛坑上'},
#  {'start': 1292.0, 'end': 1293.0, 'text': '睡一只十紧上面'},
#  {'start': 1294.0, 'end': 1295.0, 'text': '驾着两块木板'},
#  {'start': 1296.0, 'end': 1297.0, 'text': '他坐在上面晒太阳'},
#  {'start': 1298.0, 'end': 1299.0, 'text': '洗着汉银'},
#  {'start': 1300.0, 'end': 1302.0, 'text': '新娘的航列在台面前经过'},
#  {'start': 1303.0, 'end': 1305.0, 'text': '他微笑着像他们点头招呼'},
#  {'start': 1306.0, 'end': 1307.0, 'text': '待会儿早点来呀大爷'},
#  {'start': 1308.0, 'end': 1310.0, 'text': '经跟向他喊着'},
#  {'start': 1311.0, 'end': 1314.0, 'text': '物不了吃我们姑娘的洗酒'},
#  {'start': 1315.0, 'end': 1316.0, 'text': '他高生说导'},
#  {'start': 1317.0, 'end': 1319.0, 'text': '老头子下不光流流的'},
#  {'start': 1320.0, 'end': 1321.0, 'text': '连上虽然买是皱文'},
#  {'start': 1322.0, 'end': 1324.0, 'text': '依旧是一张很亲秀的隔带里'},
#  {'start': 1325.0, 'end': 1326.0, 'text': '简直有点像个女孩子'},
#  {'start': 1327.0, 'end': 1328.0, 'text': '受受的身材'},
#  {'start': 1329.0, 'end': 1330.0, 'text': '棉跑上面'},
#  {'start': 1331.0, 'end': 1333.0, 'text': '记着一条有者肉的蓝捕捉情'},
#  {'start': 1334.0, 'end': 1335.0, 'text': '他的眼睛有点毛病'},
#  {'start': 1336.0, 'end': 1338.0, 'text': '白灯灯水汪汪的'},
#  {'start': 1339.0, 'end': 1340.0, 'text': '已经半瞎了'},
#  {'start': 1341.0, 'end': 1342.0, 'text': '他得要撒椒四的外着头'},
#  {'start': 1342.0, 'end': 1345.0, 'text': '从某一个角度忘过来才看得清楚'},
#  {'start': 1346.0, 'end': 1348.0, 'text': '太阳快落山的时候'},
#  {'start': 1349.0, 'end': 1351.0, 'text': '他和谈大娘带着几个孙子来到周村'},
#  {'start': 1352.0, 'end': 1354.0, 'text': '把媳妇留在家里看家'},
#  {'start': 1355.0, 'end': 1357.0, 'text': '周家已经坐下来吃洗酒了'},
#  {'start': 1358.0, 'end': 1361.0, 'text': '新郎新娘坐在正中的一桌的上方'},
#  {'start': 1362.0, 'end': 1365.0, 'text': '两人凶钱都带着一朵大红花'},
#  {'start': 1366.0, 'end': 1368.0, 'text': '协阳设计拿黑暗的房间里'},
#  {'start': 1369.0, 'end': 1370.0, 'text': '物谋谋得一道光'},
#  {'start': 1370.0, 'end': 1373.0, 'text': '新娘子坐在那满事服务城的阳光里'},
#  {'start': 1374.0, 'end': 1376.0, 'text': '向一个红红白白的一人'},
#  {'start': 1377.0, 'end': 1380.0, 'text': '看上去有一种不真实的感觉'},
#  {'start': 1381.0, 'end': 1382.0, 'text': '12月又很奇異'},
#  {'start': 1383.0, 'end': 1385.0, 'text': '房服势永久长存的'},
#  {'start': 1386.0, 'end': 1387.0, 'text': '金根是新星'},
#  {'start': 1388.0, 'end': 1390.0, 'text': '也是坐在上手在另一桌上'},
#  {'start': 1391.0, 'end': 1394.0, 'text': '谈老大谈大娘被主人领到另一桌上'},
#  {'start': 1395.0, 'end': 1396.0, 'text': '经过一番千姓'},
#  {'start': 1396.0, 'end': 1399.0, 'text': '结果也是被迫坐在上手'},
#  {'start': 1400.0, 'end': 1404.0, 'text': '有好几个年轻的女人在旁边穿桌来往照聊着'},
#  {'start': 1405.0, 'end': 1407.0, 'text': '大改都是她家的媳妇'},
#  {'start': 1408.0, 'end': 1410.0, 'text': '谈老大精池的地着头'},
#  {'start': 1411.0, 'end': 1413.0, 'text': '捧着饭晚假装出吃饭的样子'},
#  {'start': 1414.0, 'end': 1417.0, 'text': '12用坏子减两历米送到口里'},
#  {'start': 1418.0, 'end': 1420.0, 'text': '坐为洗衍来看'},
#  {'start': 1421.0, 'end': 1422.0, 'text': '今天的菜很差'},
#  {'start': 1423.0, 'end': 1424.0, 'text': '连一大婚都没有'},
#  {'start': 1425.0, 'end': 1428.0, 'text': '但是新郎的母亲是一个阴情的主覆'},
#  {'start': 1429.0, 'end': 1430.0, 'text': '这一桌赚到那一桌'},
#  {'start': 1431.0, 'end': 1432.0, 'text': '招待的十分周到'},
#  {'start': 1433.0, 'end': 1435.0, 'text': '虽然她年龄大脚又小'},
#  {'start': 1436.0, 'end': 1438.0, 'text': '动作却非常厉乱'},
#  {'start': 1439.0, 'end': 1441.0, 'text': '她注意到谈老大直吃白饭'},
#  {'start': 1442.0, 'end': 1443.0, 'text': '她连忙飞到她身边'},
#  {'start': 1444.0, 'end': 1445.0, 'text': '向一支大儿黑的'},
#  {'start': 1446.0, 'end': 1447.0, 'text': '越有点发服的湖底'},
#  {'start': 1449.0, 'end': 1451.0, 'text': '没有什么东西给你吃'},
#  {'start': 1452.0, 'end': 1453.0, 'text': '饭总要吃饱的'},
#  {'start': 1454.0, 'end': 1455.0, 'text': '她一个冷不防'},
#  {'start': 1456.0, 'end': 1458.0, 'text': '把她面前的一碗东旋炒肉丝拿起来'},
#  {'start': 1459.0, 'end': 1460.0, 'text': '向她玩礼盗'},
#  {'start': 1461.0, 'end': 1464.0, 'text': '半碗炒肉丝全都到到她饭晚里去了'},
#  {'start': 1465.0, 'end': 1466.0, 'text': '她几起来了'},
#  {'start': 1467.0, 'end': 1469.0, 'text': '气候火的站起来要大家平礼'},
#  {'start': 1470.0, 'end': 1471.0, 'text': '大生让着'},
#  {'start': 1471.0, 'end': 1472.0, 'text': '这叫我怎么吃'},
#  {'start': 1473.0, 'end': 1474.0, 'text': '连饭都看不见了吗'},
#  {'start': 1475.0, 'end': 1476.0, 'text': '叫我怎么吃'},
#  {'start': 1477.0, 'end': 1478.0, 'text': '但是她终于安静了下来'},
#  {'start': 1479.0, 'end': 1480.0, 'text': '坐下来微微区区的'},
#  {'start': 1480.0, 'end': 1481.0, 'text': '耐心的用坏子'},
#  {'start': 1482.0, 'end': 1484.0, 'text': '挖掘炒肉丝下面埋着的饭'},
#  {'start': 1485.0, 'end': 1487.0, 'text': '洗酒吃了一半'},
#  {'start': 1487.0, 'end': 1489.0, 'text': '粥村的干不来了'},
#  {'start': 1490.0, 'end': 1491.0, 'text': '是一个费通纸'},
#  {'start': 1492.0, 'end': 1493.0, 'text': '年纪很轻'},
#  {'start': 1493.0, 'end': 1495.0, 'text': '连家股崩崩的'},
#  {'start': 1496.0, 'end': 1497.0, 'text': '脸色很严肃'},
#  {'start': 1498.0, 'end': 1499.0, 'text': '他学着老干部的作风'},
#  {'start': 1500.0, 'end': 1502.0, 'text': '向金根他们村里的王同之一样'},
#  {'start': 1503.0, 'end': 1505.0, 'text': '把棉制服穿得非常丧'},
#  {'start': 1506.0, 'end': 1507.0, 'text': '表示她忙于为人民服务'},
#  {'start': 1508.0, 'end': 1510.0, 'text': '没有时间顾到自己本身'},
#  {'start': 1511.0, 'end': 1513.0, 'text': '亮经经的一块油泥'},
#  {'start': 1514.0, 'end': 1515.0, 'text': '从领口向下深展着'},
#  {'start': 1516.0, 'end': 1517.0, 'text': '成为一个非自行'},
#  {'start': 1518.0, 'end': 1521.0, 'text': '她也继续保持老党员中的群众工作者'},
#  {'start': 1521.0, 'end': 1524.0, 'text': '在腰带后面业着一条毛巾'},
#  {'start': 1525.0, 'end': 1526.0, 'text': '带替手怕'},
#  {'start': 1527.0, 'end': 1528.0, 'text': '那是在战争期间从日本'},
#  {'start': 1529.0, 'end': 1530.0, 'text': '兵那里传来的封启'},
#  {'start': 1531.0, 'end': 1533.0, 'text': '金根也绔笑着这半发'},
#  {'start': 1534.0, 'end': 1536.0, 'text': '在她的库带后面业着一条毛巾'},
#  {'start': 1537.0, 'end': 1538.0, 'text': '有棉好折着'},
#  {'start': 1539.0, 'end': 1541.0, 'text': '直路出一点点毛巾的下端'},
#  {'start': 1542.0, 'end': 1544.0, 'text': '但是这已经使她有点害羞'},
#  {'start': 1545.0, 'end': 1546.0, 'text': '绔夫在学时毛'},
#  {'start': 1547.0, 'end': 1550.0, 'text': '毛巾是她女人从上海给稍来的'},
#  {'start': 1551.0, 'end': 1553.0, 'text': '处心因为从来不做别用'},
#  {'start': 1554.0, 'end': 1556.0, 'text': '下面还有四个红字'},
#  {'start': 1557.0, 'end': 1558.0, 'text': '铸鸡早安'},
#  {'start': 1559.0, 'end': 1562.0, 'text': '大家都站起来让费同之座'},
#  {'start': 1563.0, 'end': 1564.0, 'text': '千让在三'},
#  {'start': 1565.0, 'end': 1567.0, 'text': '结果是老夫人挪到旁边去'},
#  {'start': 1568.0, 'end': 1570.0, 'text': '让她和她丈夫病座在上手'},
#  {'start': 1571.0, 'end': 1573.0, 'text': '今天这洗衣并没有久'},
#  {'start': 1574.0, 'end': 1575.0, 'text': '但是在这样冷的天'},
#  {'start': 1576.0, 'end': 1578.0, 'text': '房间热红红的几买的人'},
#  {'start': 1578.0, 'end': 1581.0, 'text': '再加上空心肚子吃了两碗饱饭'},
#  {'start': 1582.0, 'end': 1585.0, 'text': '没有久也带了两分九亿'},
#  {'start': 1586.0, 'end': 1588.0, 'text': '大家都吃的脸红红的'},
#  {'start': 1589.0, 'end': 1590.0, 'text': '衣服九含耳热的样子'},
#  {'start': 1592.0, 'end': 1594.0, 'text': '费同之人很合起'},
#  {'start': 1595.0, 'end': 1596.0, 'text': '性质也好'},
#  {'start': 1597.0, 'end': 1598.0, 'text': '主义问在座的客人们'},
#  {'start': 1599.0, 'end': 1600.0, 'text': '今年收成怎样'},
#  {'start': 1601.0, 'end': 1602.0, 'text': '收了多少蛋米多少金麻'},
#  {'start': 1603.0, 'end': 1606.0, 'text': '经跟秋收的时候工作努力'},
#  {'start': 1607.0, 'end': 1608.0, 'text': '选上了老母'},
#  {'start': 1609.0, 'end': 1611.0, 'text': '谈大娘替她卓食宣言了一分'},
#  {'start': 1612.0, 'end': 1614.0, 'text': '她能延善道有说有效的'},
#  {'start': 1615.0, 'end': 1616.0, 'text': '夫眼的面面据到'},
#  {'start': 1617.0, 'end': 1620.0, 'text': '她从这费同之说了不少的话'},
#  {'start': 1621.0, 'end': 1624.0, 'text': '有时候她的话与当时的话题'},
#  {'start': 1625.0, 'end': 1626.0, 'text': '并没有直接的关系'},
#  {'start': 1627.0, 'end': 1629.0, 'text': '但是永远是节拍错的很准'},
#  {'start': 1629.0, 'end': 1632.0, 'text': '有百优言有枪有掉'},
#  {'start': 1633.0, 'end': 1635.0, 'text': '有现在好路'},
#  {'start': 1636.0, 'end': 1637.0, 'text': '穷人翻身了'},
#  {'start': 1638.0, 'end': 1640.0, 'text': '现在跟从前两样路'},
#  {'start': 1641.0, 'end': 1642.0, 'text': '要不是毛主席'},
#  {'start': 1643.0, 'end': 1644.0, 'text': '我们哪有今天'},
#  {'start': 1645.0, 'end': 1646.0, 'text': '要不是革命党来了'},
#  {'start': 1647.0, 'end': 1648.0, 'text': '我们穷人受罪'},
#  {'start': 1649.0, 'end': 1650.0, 'text': '不知道受到哪年'},
#  {'start': 1652.0, 'end': 1654.0, 'text': '谈大娘把共产党与革命党'},
#  {'start': 1655.0, 'end': 1656.0, 'text': '有点搞不清楚'},
#  {'start': 1656.0, 'end': 1659.0, 'text': '她一直成共产党为革命的'},
#  {'start': 1660.0, 'end': 1663.0, 'text': '有时候甚至于成她为国民党'},
#  {'start': 1664.0, 'end': 1666.0, 'text': '但是在她这年龄'},
#  {'start': 1667.0, 'end': 1669.0, 'text': '这错误似乎情有可怨'},
#  {'start': 1670.0, 'end': 1671.0, 'text': '整个地说来'},
#  {'start': 1672.0, 'end': 1674.0, 'text': '她给费同志的印象相当好'},
#  {'start': 1675.0, 'end': 1678.0, 'text': '难得看见她这样前进的老太婆'},
#  {'start': 1679.0, 'end': 1681.0, 'text': '她逼着心狼的母亲多吃一点'},
#  {'start': 1682.0, 'end': 1683.0, 'text': '说'},
#  {'start': 1683.0, 'end': 1685.0, 'text': '你只顾毛别人了'},
#  {'start': 1686.0, 'end': 1687.0, 'text': '自己饿肚子'},
#  {'start': 1688.0, 'end': 1690.0, 'text': '女主人提阿朝夹菜'},
#  {'start': 1691.0, 'end': 1693.0, 'text': '谈大娘就有对阿朝说'},
#  {'start': 1694.0, 'end': 1696.0, 'text': '你姑姑今天也不回去'},
#  {'start': 1697.0, 'end': 1698.0, 'text': '你愿意跟着你姑姑'},
#  {'start': 1699.0, 'end': 1700.0, 'text': '也住下吧'},
#  {'start': 1701.0, 'end': 1702.0, 'text': '不是舍不得她吗'},
#  {'start': 1703.0, 'end': 1705.0, 'text': '昨天不是还哭了吧'},
#  {'start': 1706.0, 'end': 1709.0, 'text': '那小女孩安静的细誓吃她的饭'},
#  {'start': 1710.0, 'end': 1711.0, 'text': '她的眼睛无沉沉的'},
#  {'start': 1711.0, 'end': 1713.0, 'text': '一点也没有激动的样子'},
#  {'start': 1714.0, 'end': 1716.0, 'text': '谈大娘又下乎她'},
#  {'start': 1717.0, 'end': 1719.0, 'text': '我们走了不带你走'},
#  {'start': 1720.0, 'end': 1722.0, 'text': '你爹今天不带你回去了'},
#  {'start': 1723.0, 'end': 1725.0, 'text': '你想有这么容易的事呀'},
#  {'start': 1726.0, 'end': 1728.0, 'text': '吃饱了肚子 摸摸嘴上的油'},
#  {'start': 1729.0, 'end': 1730.0, 'text': '站起来就走'},
#  {'start': 1731.0, 'end': 1732.0, 'text': '把你卖给人家漏'},
#  {'start': 1733.0, 'end': 1734.0, 'text': '大家都笑了'},
#  {'start': 1735.0, 'end': 1736.0, 'text': '女主人说'},
#  {'start': 1737.0, 'end': 1739.0, 'text': '你打今天起'},
#  {'start': 1739.0, 'end': 1740.0, 'text': '就住这了'},
#  {'start': 1741.0, 'end': 1742.0, 'text': '不回去'},
#  {'start': 1743.0, 'end': 1744.0, 'text': '那孩子没有说什么'},
#  {'start': 1745.0, 'end': 1747.0, 'text': '也许她是被一重重的一句包围着'},
#  {'start': 1748.0, 'end': 1749.0, 'text': '也许不'},
#  {'start': 1750.0, 'end': 1751.0, 'text': '完全看不出来'},
#  {'start': 1752.0, 'end': 1753.0, 'text': '但是一吃完了饭'},
#  {'start': 1754.0, 'end': 1755.0, 'text': '她就跑到金根旁边'},
#  {'start': 1756.0, 'end': 1758.0, 'text': '拉住她的手 一直不放松'},
#  {'start': 1759.0, 'end': 1760.0, 'text': '她走到哪里'},
#  {'start': 1760.0, 'end': 1761.0, 'text': '她都跟来根曲'},
#  {'start': 1763.0, 'end': 1765.0, 'text': '吃完了洗酒 照理闹房'},
#  {'start': 1766.0, 'end': 1767.0, 'text': '不过今天'},
#  {'start': 1767.0, 'end': 1769.0, 'text': '大家房服都有点顾忌'},
#  {'start': 1770.0, 'end': 1771.0, 'text': '因为有干部在做'},
#  {'start': 1772.0, 'end': 1773.0, 'text': '但是费同职'},
#  {'start': 1774.0, 'end': 1776.0, 'text': '显然是要与民同乐的样子'},
#  {'start': 1776.0, 'end': 1777.0, 'text': '还领着头起哄'},
#  {'start': 1778.0, 'end': 1781.0, 'text': '因此大家也就见见的热闹起来了'},
#  {'start': 1782.0, 'end': 1783.0, 'text': '有一个人喊着'},
#  {'start': 1784.0, 'end': 1785.0, 'text': '要信勒心娘拉手'},
#  {'start': 1786.0, 'end': 1789.0, 'text': '谈大娘做了心娘的代言人'},
#  {'start': 1789.0, 'end': 1790.0, 'text': '替她推妥'},
#  {'start': 1790.0, 'end': 1791.0, 'text': '又替她还嫁'},
#  {'start': 1792.0, 'end': 1794.0, 'text': '征录了半天之后'},
#  {'start': 1794.0, 'end': 1795.0, 'text': '是谈大娘让了部'},
#  {'start': 1796.0, 'end': 1797.0, 'text': '把心郎心娘的手'},
#  {'start': 1797.0, 'end': 1798.0, 'text': '牵到一起'},
#  {'start': 1798.0, 'end': 1800.0, 'text': '算是握了一握'},
#  {'start': 1801.0, 'end': 1803.0, 'text': '然后又有人要求心娘'},
#  {'start': 1803.0, 'end': 1804.0, 'text': '坐在心郎膝盖上'},
#  {'start': 1805.0, 'end': 1806.0, 'text': '叫一声歌歌'},
#  {'start': 1807.0, 'end': 1808.0, 'text': '这要求一提出来'},
#  {'start': 1808.0, 'end': 1810.0, 'text': '大家都笑不可养'},
#  {'start': 1811.0, 'end': 1812.0, 'text': '心郎急了'},
#  {'start': 1812.0, 'end': 1814.0, 'text': '想留又给拉了回来'},
#  {'start': 1814.0, 'end': 1816.0, 'text': '那在床延上坐下'},
#  {'start': 1817.0, 'end': 1820.0, 'text': '这一次的焦射更费时间了'},
#  {'start': 1821.0, 'end': 1822.0, 'text': '好好好'},
#  {'start': 1822.0, 'end': 1824.0, 'text': '那我最胸的一个人'},
#  {'start': 1824.0, 'end': 1825.0, 'text': '终于气氛分的说'},
#  {'start': 1826.0, 'end': 1827.0, 'text': '心娘子不给面子'},
#  {'start': 1828.0, 'end': 1831.0, 'text': '有说说你别生气'},
#  {'start': 1832.0, 'end': 1834.0, 'text': '谈大娘照着心娘的称呼'},
#  {'start': 1834.0, 'end': 1835.0, 'text': '向她陪里'},
#  {'start': 1836.0, 'end': 1838.0, 'text': '那叫心娘子'},
#  {'start': 1838.0, 'end': 1839.0, 'text': '给你到晚茶'},
#  {'start': 1840.0, 'end': 1841.0, 'text': '谁要吃什么茶'},
#  {'start': 1843.0, 'end': 1845.0, 'text': '心娘始终地只投作着'},
#  {'start': 1845.0, 'end': 1846.0, 'text': '一动也不动'}]

# %%
test_audio.write_file()
# Out:
# File already exists

# %%
# batch processing
def batch_process_audio(audio_file_paths):
    audio_objects = []
    for audio_file_path in audio_file_paths:
        audio_objects.append(AudioObject(audio_file_path))
    for audio_object in audio_objects:
        audio_object.get_transcription()
        audio_object.write_file()
    print("Batch processing complete")
    return

# %%
# get all paths of all audio files in the audio folder
audio_file_paths = []
for root, dirs, files in os.walk("./audio"):
    for file in files:
        if file.endswith(".mp3"):
            audio_file_paths.append(os.path.join(root, file))
audio_file_paths
# Out:
# ['./audio/test0.mp3', './audio/test1.mp3']

# %%
batch_process_audio(audio_file_paths)
# Out:
# /Users/ihhi/opt/anaconda3/lib/python3.9/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcription created
# Transcription already available
# File test0.txt created
# /Users/ihhi/opt/anaconda3/lib/python3.9/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Transcription created
# Transcription already available
# File test1.txt created
# Batch processing complete
