# %%
import google.generativeai as genai
import os
import json
import sys
import time
from dotenv import load_dotenv
import google.api_core.exceptions
from pathlib import Path
import random

# %%
# --- Configuration ---
# Set your API Key (replace 'YOUR_API_KEY' or use environment variable)
load_dotenv()  # Load environment variables from .env file if it exists
API_KEY = os.getenv('GOOGLE_API_KEY')
# Or uncomment and set directly (less secure):
# API_KEY = 'YOUR_API_KEY'

if not API_KEY:
    raise ValueError("GOOGLE_API_KEY environment variable not set.")

genai.configure(api_key=API_KEY)

PDF_FOLDER = Path("./PDFs")
OUTPUT_FOLDER = Path("./descriptions_summaries")
# MODEL_NAME = "gemini-1.5-flash-8b"
MODEL_NAME = "gemini-2.0-flash-lite-001"

# Create output directory if it doesn't exist
OUTPUT_FOLDER.mkdir(parents=True, exist_ok=True)

# Model Configuration (Optional)
generation_config = {
    "temperature": 0.7,
    "top_p": 1,
    "top_k": 1,
    # Adjust max_output_tokens if needed based on expected description lengths
    "max_output_tokens": 8192,
    "response_mime_type": "application/json", # Ask Gemini to output JSON directly
}

safety_settings = [
    {"category": "HARM_CATEGORY_HARASSMENT", "threshold": "BLOCK_MEDIUM_AND_ABOVE"},
    {"category": "HARM_CATEGORY_HATE_SPEECH", "threshold": "BLOCK_MEDIUM_AND_ABOVE"},
    {"category": "HARM_CATEGORY_SEXUALLY_EXPLICIT", "threshold": "BLOCK_MEDIUM_AND_ABOVE"},
    {"category": "HARM_CATEGORY_DANGEROUS_CONTENT", "threshold": "BLOCK_MEDIUM_AND_ABOVE"},
]

# --- Helper Function to build the prompt ---
def build_prompt(video_filename_stem):
    return rf"""
Analyze the provided PDF file. Each page contains a chronologically ordered image sampled from a video named '{video_filename_stem}'.

Instructions:
1. For EACH page (image) in the PDF:
    a. Generate a short, coherent description in Chinese. Be logical based on the sequence of images.
    b. Identify distinct content blocks within the image (visual elements, text).
    c. For each content block, specify its 'content' (the description or the text itself), 'type' (e.g., '图像', '中文文字', '英文文字'), and 'position' (e.g., '正中央', '左上角', '最下方中间').
    d. If the content is non-Chinese text, provide the original text followed by a Chinese translation in the format: '<Original Text>（翻译：<Translated Text>）'.
    e. Ignore any consistent watermarks often found in corners (in most cases "bilibili")
2. After analyzing ALL pages:
    a. Generate a concise overall 'title' for the video in Chinese (around 15-30 characters).
    b. Generate a 'summary' of the video's key events or theme in Chinese (around 50-100 words).
3. Return the *entire* result STRICTLY as a single JSON object matching the following structure. Do NOT include any text before or after the JSON object.

```json
{{
  "video": "{video_filename_stem}",
  "descriptions": [
    {{"image0": [ {{"content": "...", "type": "...", "position": "..."}}, ... ]}},
    {{"image1": [ {{"content": "...", "type": "...", "position": "..."}}, ... ]}},
    // ... continue for all pages/images, numbering sequentially starting from image0
  ],
  "title": "...",
  "summary": "..."
}}
```
Ensure the final output is valid JSON.
"""

# --- Main Processing Loop ---
print(f"Starting PDF analysis from folder: {PDF_FOLDER}")
print(f"Outputting JSON to folder: {OUTPUT_FOLDER}")
print("-" * 30)

processed_count = 0
skipped_count = 0
error_count = 0

# List all PDF files in the input directory
pdf_files = sorted([f for f in PDF_FOLDER.glob("*.pdf") if f.is_file()], reverse=True)
random.shuffle(pdf_files)

if not pdf_files:
    print(f"No PDF files found in {PDF_FOLDER}. Exiting.")
else:
    print(f"Found {len(pdf_files)} PDF files to potentially process.")

for pdf_path in pdf_files:
    video_name = pdf_path.stem # Get filename without extension
    output_json_path = OUTPUT_FOLDER / f"{video_name}.json"
    print(f"\nChecking: {pdf_path.name}")

    # Skip if JSON already exists
    if output_json_path.exists():
        print(f"  Skipping: Output file '{output_json_path.name}' already exists.")
        skipped_count += 1
        continue

    print(f"  Processing: {pdf_path.name}")

    try:
        # 1. Upload the PDF file
        print(f"    Uploading '{pdf_path.name}'...")
        # The API automatically detects the MIME type for PDF when uploading
        uploaded_file = genai.upload_file(path=pdf_path)
        print(f"    Upload successful: {uploaded_file.name}")

        # Add a small delay after upload, sometimes helpful
        time.sleep(2)

        # 2. Prepare the prompt and input for the model
        prompt_text = build_prompt(video_name)
        model_input = [prompt_text, uploaded_file] # Combine prompt and file

        # 3. Instantiate the model
        model = genai.GenerativeModel(
            model_name=MODEL_NAME,
            safety_settings=safety_settings,
            generation_config=generation_config
        )

        # 4. Generate content
        print("    Generating descriptions and summary...")
        response = model.generate_content(model_input, stream=False) # Use stream=False for simpler handling

        # 5. Process the response
        print("    Parsing response...")
        response_text = response.text

        # Clean potential markdown code fences if Gemini wraps the JSON
        if response_text.strip().startswith("```json"):
            response_text = response_text.strip()[7:-3].strip()
        elif response_text.strip().startswith("```"):
            response_text = response_text.strip()[3:-3].strip()


        # Validate and save JSON
        try:
            result_json = json.loads(response_text)

            # Basic validation (check top-level keys) - can be more thorough
            required_keys = ["video", "descriptions", "title", "summary"]
            if not all(key in result_json for key in required_keys):
                raise ValueError("Generated JSON missing required keys.")
            if not isinstance(result_json["descriptions"], list):
                raise ValueError("'descriptions' field is not a list.")

            # Ensure the video name matches (optional but good practice)
            if result_json.get("video") != video_name:
                print(f"    Warning: Generated video name '{result_json.get('video')}' doesn't match filename '{video_name}'. Using filename.")
                result_json["video"] = video_name

            # Save the valid JSON
            with open(output_json_path, 'w', encoding='utf-8') as f:
                json.dump(result_json, f, ensure_ascii=False, indent=2)
            print(f"    Success: Saved results to '{output_json_path.name}'")
            processed_count += 1

            # Clean up the uploaded file from the API storage after successful processing
            print(f"    Deleting uploaded file '{uploaded_file.name}' from API storage...")
            try:
                genai.delete_file(uploaded_file.name)
                print("    Uploaded file deleted successfully.")
            except Exception as delete_err:
                print(f"    Warning: Could not delete uploaded file '{uploaded_file.name}': {delete_err}")


        except json.JSONDecodeError as json_err:
            print(f"  ERROR: Failed to parse JSON response for '{pdf_path.name}'. Skipping.")
            print(f"    Error details: {json_err}")
            print(f"    Received text: {response_text[:500]}...") # Print beginning of bad response
            error_count += 1
            # Attempt to delete the uploaded file even if parsing failed
            print(f"    Attempting to delete uploaded file '{uploaded_file.name}' after error...")
            try:
                genai.delete_file(uploaded_file.name)
                print("    Uploaded file deleted successfully.")
            except Exception as delete_err:
                print(f"    Warning: Could not delete uploaded file '{uploaded_file.name}': {delete_err}")


        except ValueError as val_err:
            print(f"  ERROR: Generated JSON structure invalid for '{pdf_path.name}'. Skipping.")
            print(f"    Error details: {val_err}")
            print(f"    Received JSON: {result_json}") # Print the invalid JSON structure
            error_count += 1
            # Attempt to delete the uploaded file even if validation failed
            print(f"    Attempting to delete uploaded file '{uploaded_file.name}' after error...")
            try:
                genai.delete_file(uploaded_file.name)
                print("    Uploaded file deleted successfully.")
            except Exception as delete_err:
                print(f"    Warning: Could not delete uploaded file '{uploaded_file.name}': {delete_err}")


    except Exception as e:
        print(f"  ERROR: An unexpected error occurred while processing '{pdf_path.name}': {e}")
        error_count += 1
        # If file was uploaded before error, try to delete it (variable might not exist if upload failed)
        if 'uploaded_file' in locals() and uploaded_file is not None and hasattr(uploaded_file, 'name'):
            print(f"    Attempting to delete potentially uploaded file '{uploaded_file.name}' after error...")
            try:
                genai.delete_file(uploaded_file.name)
                print("    Uploaded file deleted successfully.")
            except Exception as delete_err:
                print(f"    Warning: Could not delete uploaded file '{uploaded_file.name}': {delete_err}")
        # Reset variable to avoid issues in next loop iteration's error handling
        uploaded_file = None


    # Optional: Add a delay between processing files to avoid hitting rate limits
    time.sleep(5) # Adjust sleep time as needed (e.g., 2-10 seconds)
    print("-" * 30)
    print("Processing Complete.")
    print(f"Successfully processed: {processed_count} files")
    print(f"Skipped (already exist): {skipped_count} files")
    print(f"Errors encountered: {error_count} files")
# Out:
# Starting PDF analysis from folder: PDFs
# Outputting JSON to folder: descriptions_summaries
# ------------------------------
# Found 4199 PDF files to potentially process.
#
# Checking: BV1XQ1PYXE3r.pdf
#   Processing: BV1XQ1PYXE3r.pdf
#     Uploading 'BV1XQ1PYXE3r.pdf'...
#     Upload successful: files/y2v62ulk859c
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1XQ1PYXE3r.json'
#     Deleting uploaded file 'files/y2v62ulk859c' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 1 files
# Skipped (already exist): 0 files
# Errors encountered: 0 files
#
# Checking: BV1L4PaeJEdj.pdf
#   Processing: BV1L4PaeJEdj.pdf
#     Uploading 'BV1L4PaeJEdj.pdf'...
#     Upload successful: files/hgpeutey15xc
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1L4PaeJEdj.json'
#     Deleting uploaded file 'files/hgpeutey15xc' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 2 files
# Skipped (already exist): 0 files
# Errors encountered: 0 files
#
# Checking: BV1vs6BYrEpY.pdf
#   Processing: BV1vs6BYrEpY.pdf
#     Uploading 'BV1vs6BYrEpY.pdf'...
#     Upload successful: files/srts8kn7ih53
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1vs6BYrEpY.json'
#     Deleting uploaded file 'files/srts8kn7ih53' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 3 files
# Skipped (already exist): 0 files
# Errors encountered: 0 files
#
# Checking: BV1uS421o7g4.pdf
#   Processing: BV1uS421o7g4.pdf
#     Uploading 'BV1uS421o7g4.pdf'...
#     Upload successful: files/eqw3l5sy0qfd
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1uS421o7g4.json'
#     Deleting uploaded file 'files/eqw3l5sy0qfd' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 4 files
# Skipped (already exist): 0 files
# Errors encountered: 0 files
#
# Checking: BV1Nz421v7Q8.pdf
#   Processing: BV1Nz421v7Q8.pdf
#     Uploading 'BV1Nz421v7Q8.pdf'...
#     Upload successful: files/52bnw8tgvtb5
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1Nz421v7Q8.json'
#     Deleting uploaded file 'files/52bnw8tgvtb5' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 5 files
# Skipped (already exist): 0 files
# Errors encountered: 0 files
#
# Checking: BV1aRXbYVEvT.pdf
#   Processing: BV1aRXbYVEvT.pdf
#     Uploading 'BV1aRXbYVEvT.pdf'...
#     Upload successful: files/4vhs4piyx3av
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1aRXbYVEvT.json'
#     Deleting uploaded file 'files/4vhs4piyx3av' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 6 files
# Skipped (already exist): 0 files
# Errors encountered: 0 files
#
# Checking: BV1LpZsY7EFw.pdf
#   Processing: BV1LpZsY7EFw.pdf
#     Uploading 'BV1LpZsY7EFw.pdf'...
#     Upload successful: files/j73wnjv569h1
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1LpZsY7EFw.json'
#     Deleting uploaded file 'files/j73wnjv569h1' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 7 files
# Skipped (already exist): 0 files
# Errors encountered: 0 files
#
# Checking: BV1RY411b7GQ.pdf
#   Processing: BV1RY411b7GQ.pdf
#     Uploading 'BV1RY411b7GQ.pdf'...
#     Upload successful: files/dqucr7xss6mw
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1RY411b7GQ.json'
#     Deleting uploaded file 'files/dqucr7xss6mw' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 8 files
# Skipped (already exist): 0 files
# Errors encountered: 0 files
#
# Checking: BV1TcorYCEVs.pdf
#   Processing: BV1TcorYCEVs.pdf
#     Uploading 'BV1TcorYCEVs.pdf'...
#     Upload successful: files/9r7etxex0jdz
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1TcorYCEVs.json'
#     Deleting uploaded file 'files/9r7etxex0jdz' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 9 files
# Skipped (already exist): 0 files
# Errors encountered: 0 files
#
# Checking: BV1xgCKYkEEM.pdf
#   Skipping: Output file 'BV1xgCKYkEEM.json' already exists.
#
# Checking: BV1YnePeyE85.pdf
#   Processing: BV1YnePeyE85.pdf
#     Uploading 'BV1YnePeyE85.pdf'...
#     Upload successful: files/p42n2hkqfkoi
#     Generating descriptions and summary...
#     Parsing response...
#   ERROR: An unexpected error occurred while processing 'BV1YnePeyE85.pdf': ("Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 3. The candidate's safety_ratings are: [category: HARM_CATEGORY_HATE_SPEECH\nprobability: LOW\n, category: HARM_CATEGORY_DANGEROUS_CONTENT\nprobability: MEDIUM\nblocked: true\n, category: HARM_CATEGORY_HARASSMENT\nprobability: NEGLIGIBLE\n, category: HARM_CATEGORY_SEXUALLY_EXPLICIT\nprobability: NEGLIGIBLE\n].", [category: HARM_CATEGORY_HATE_SPEECH
# probability: LOW
# , category: HARM_CATEGORY_DANGEROUS_CONTENT
# probability: MEDIUM
# blocked: true
# , category: HARM_CATEGORY_HARASSMENT
# probability: NEGLIGIBLE
# , category: HARM_CATEGORY_SEXUALLY_EXPLICIT
# probability: NEGLIGIBLE
# ])
#     Attempting to delete potentially uploaded file 'files/p42n2hkqfkoi' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 9 files
# Skipped (already exist): 1 files
# Errors encountered: 1 files
#
# Checking: BV1usQVYREWa.pdf
#   Processing: BV1usQVYREWa.pdf
#     Uploading 'BV1usQVYREWa.pdf'...
#     Upload successful: files/igfddz26457x
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1usQVYREWa.json'
#     Deleting uploaded file 'files/igfddz26457x' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 10 files
# Skipped (already exist): 1 files
# Errors encountered: 1 files
#
# Checking: BV1axfSYLEuY.pdf
#   Processing: BV1axfSYLEuY.pdf
#     Uploading 'BV1axfSYLEuY.pdf'...
#     Upload successful: files/v8w8qsnae3hz
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1axfSYLEuY.json'
#     Deleting uploaded file 'files/v8w8qsnae3hz' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 11 files
# Skipped (already exist): 1 files
# Errors encountered: 1 files
#
# Checking: BV1gm41127nv.pdf
#   Processing: BV1gm41127nv.pdf
#     Uploading 'BV1gm41127nv.pdf'...
#     Upload successful: files/k41r1ey54fn1
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1gm41127nv.json'
#     Deleting uploaded file 'files/k41r1ey54fn1' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 12 files
# Skipped (already exist): 1 files
# Errors encountered: 1 files
#
# Checking: BV1dzZgYuExq.pdf
#   Processing: BV1dzZgYuExq.pdf
#     Uploading 'BV1dzZgYuExq.pdf'...
#     Upload successful: files/zfndgdtiyzsw
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1dzZgYuExq.json'
#     Deleting uploaded file 'files/zfndgdtiyzsw' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 13 files
# Skipped (already exist): 1 files
# Errors encountered: 1 files
#
# Checking: BV1RXo9YxEwi.pdf
#   Skipping: Output file 'BV1RXo9YxEwi.json' already exists.
#
# Checking: BV1W5ZbYuEUb.pdf
#   Skipping: Output file 'BV1W5ZbYuEUb.json' already exists.
#
# Checking: BV1Hh4y1L7hF.pdf
#   Processing: BV1Hh4y1L7hF.pdf
#     Uploading 'BV1Hh4y1L7hF.pdf'...
#     Upload successful: files/b7iv2seadqsx
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1Hh4y1L7hF.json'
#     Deleting uploaded file 'files/b7iv2seadqsx' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 14 files
# Skipped (already exist): 3 files
# Errors encountered: 1 files
#
# Checking: BV1R5woe2Eeu.pdf
#   Processing: BV1R5woe2Eeu.pdf
#     Uploading 'BV1R5woe2Eeu.pdf'...
#     Upload successful: files/73gv4hle0vze
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1R5woe2Eeu.json'
#     Deleting uploaded file 'files/73gv4hle0vze' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 15 files
# Skipped (already exist): 3 files
# Errors encountered: 1 files
#
# Checking: BV1HrBMYaEQD.pdf
#   Processing: BV1HrBMYaEQD.pdf
#     Uploading 'BV1HrBMYaEQD.pdf'...
#     Upload successful: files/hr26y1djhosg
#     Generating descriptions and summary...
#     Parsing response...
#   ERROR: An unexpected error occurred while processing 'BV1HrBMYaEQD.pdf': ("Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 3. The candidate's safety_ratings are: [category: HARM_CATEGORY_HATE_SPEECH\nprobability: MEDIUM\nblocked: true\n, category: HARM_CATEGORY_DANGEROUS_CONTENT\nprobability: LOW\n, category: HARM_CATEGORY_HARASSMENT\nprobability: LOW\n, category: HARM_CATEGORY_SEXUALLY_EXPLICIT\nprobability: NEGLIGIBLE\n].", [category: HARM_CATEGORY_HATE_SPEECH
# probability: MEDIUM
# blocked: true
# , category: HARM_CATEGORY_DANGEROUS_CONTENT
# probability: LOW
# , category: HARM_CATEGORY_HARASSMENT
# probability: LOW
# , category: HARM_CATEGORY_SEXUALLY_EXPLICIT
# probability: NEGLIGIBLE
# ])
#     Attempting to delete potentially uploaded file 'files/hr26y1djhosg' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 15 files
# Skipped (already exist): 3 files
# Errors encountered: 2 files
#
# Checking: BV1AjsuenE3j.pdf
#   Skipping: Output file 'BV1AjsuenE3j.json' already exists.
#
# Checking: BV1cT411t75q.pdf
#   Processing: BV1cT411t75q.pdf
#     Uploading 'BV1cT411t75q.pdf'...
#     Upload successful: files/pwqi8gvq5mzd
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1cT411t75q.json'
#     Deleting uploaded file 'files/pwqi8gvq5mzd' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 16 files
# Skipped (already exist): 4 files
# Errors encountered: 2 files
#
# Checking: BV1bof8YpEBL.pdf
#   Processing: BV1bof8YpEBL.pdf
#     Uploading 'BV1bof8YpEBL.pdf'...
#     Upload successful: files/73skvvytdea9
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1bof8YpEBL.json'
#     Deleting uploaded file 'files/73skvvytdea9' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 17 files
# Skipped (already exist): 4 files
# Errors encountered: 2 files
#
# Checking: BV1P14y197V5.pdf
#   Processing: BV1P14y197V5.pdf
#     Uploading 'BV1P14y197V5.pdf'...
#     Upload successful: files/44o94bzzrf7v
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1P14y197V5.json'
#     Deleting uploaded file 'files/44o94bzzrf7v' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 18 files
# Skipped (already exist): 4 files
# Errors encountered: 2 files
#
# Checking: BV18j41187Bp.pdf
#   Processing: BV18j41187Bp.pdf
#     Uploading 'BV18j41187Bp.pdf'...
#     Upload successful: files/9mjoicaaqget
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV18j41187Bp.json'
#     Deleting uploaded file 'files/9mjoicaaqget' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 19 files
# Skipped (already exist): 4 files
# Errors encountered: 2 files
#
# Checking: BV1pK411U7nV.pdf
#   Processing: BV1pK411U7nV.pdf
#     Uploading 'BV1pK411U7nV.pdf'...
#     Upload successful: files/eu8ei4cdqmiu
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1pK411U7nV.json'
#     Deleting uploaded file 'files/eu8ei4cdqmiu' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 20 files
# Skipped (already exist): 4 files
# Errors encountered: 2 files
#
# Checking: BV1e9ZtYXEHM.pdf
#   Processing: BV1e9ZtYXEHM.pdf
#     Uploading 'BV1e9ZtYXEHM.pdf'...
#     Upload successful: files/je0k9vfbpc0j
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1e9ZtYXEHM.json'
#     Deleting uploaded file 'files/je0k9vfbpc0j' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 21 files
# Skipped (already exist): 4 files
# Errors encountered: 2 files
#
# Checking: BV1Z34y1M7MH.pdf
#   Processing: BV1Z34y1M7MH.pdf
#     Uploading 'BV1Z34y1M7MH.pdf'...
#     Upload successful: files/zqcxwe9feypu
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1Z34y1M7MH.json'
#     Deleting uploaded file 'files/zqcxwe9feypu' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 22 files
# Skipped (already exist): 4 files
# Errors encountered: 2 files
#
# Checking: BV1aCZHYKEru.pdf
#   Skipping: Output file 'BV1aCZHYKEru.json' already exists.
#
# Checking: BV1Dm97YGE3g.pdf
#   Processing: BV1Dm97YGE3g.pdf
#     Uploading 'BV1Dm97YGE3g.pdf'...
#     Upload successful: files/53j1ebs67zp9
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1Dm97YGE3g.json'
#     Deleting uploaded file 'files/53j1ebs67zp9' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 23 files
# Skipped (already exist): 5 files
# Errors encountered: 2 files
#
# Checking: BV1vdqVYYEvP.pdf
#   Skipping: Output file 'BV1vdqVYYEvP.json' already exists.
#
# Checking: BV1HmSxY6Ew4.pdf
#   Processing: BV1HmSxY6Ew4.pdf
#     Uploading 'BV1HmSxY6Ew4.pdf'...
#     Upload successful: files/stp3i75x34hy
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1HmSxY6Ew4.json'
#     Deleting uploaded file 'files/stp3i75x34hy' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 24 files
# Skipped (already exist): 6 files
# Errors encountered: 2 files
#
# Checking: BV1u84y1L7BE.pdf
#   Processing: BV1u84y1L7BE.pdf
#     Uploading 'BV1u84y1L7BE.pdf'...
#     Upload successful: files/lh4hqkb6kts7
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1u84y1L7BE.json'
#     Deleting uploaded file 'files/lh4hqkb6kts7' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 25 files
# Skipped (already exist): 6 files
# Errors encountered: 2 files
#
# Checking: BV1mSZJYWE8J.pdf
#   Skipping: Output file 'BV1mSZJYWE8J.json' already exists.
#
# Checking: BV1MzZ4Y5E9Z.pdf
#   Processing: BV1MzZ4Y5E9Z.pdf
#     Uploading 'BV1MzZ4Y5E9Z.pdf'...
#     Upload successful: files/1h9m6hdkpsrd
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1MzZ4Y5E9Z.json'
#     Deleting uploaded file 'files/1h9m6hdkpsrd' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 26 files
# Skipped (already exist): 7 files
# Errors encountered: 2 files
#
# Checking: BV1mkD4YdE9N.pdf
#   Processing: BV1mkD4YdE9N.pdf
#     Uploading 'BV1mkD4YdE9N.pdf'...
#     Upload successful: files/m7fle3q2841g
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1mkD4YdE9N.json'
#     Deleting uploaded file 'files/m7fle3q2841g' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 27 files
# Skipped (already exist): 7 files
# Errors encountered: 2 files
#
# Checking: BV1B5FxebEak.pdf
#   Processing: BV1B5FxebEak.pdf
#     Uploading 'BV1B5FxebEak.pdf'...
#     Upload successful: files/29fm59vozmlh
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1B5FxebEak.json'
#     Deleting uploaded file 'files/29fm59vozmlh' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 28 files
# Skipped (already exist): 7 files
# Errors encountered: 2 files
#
# Checking: BV1ax4y1a7Rm.pdf
#   Processing: BV1ax4y1a7Rm.pdf
#     Uploading 'BV1ax4y1a7Rm.pdf'...
#     Upload successful: files/ex1z43lwbnrj
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1ax4y1a7Rm.json'
#     Deleting uploaded file 'files/ex1z43lwbnrj' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 29 files
# Skipped (already exist): 7 files
# Errors encountered: 2 files
#
# Checking: BV1YqkRYsELF.pdf
#   Processing: BV1YqkRYsELF.pdf
#     Uploading 'BV1YqkRYsELF.pdf'...
#     Upload successful: files/qmi5grb9f6di
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1YqkRYsELF.json'
#     Deleting uploaded file 'files/qmi5grb9f6di' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 30 files
# Skipped (already exist): 7 files
# Errors encountered: 2 files
#
# Checking: BV1uaZpYYEdE.pdf
#   Skipping: Output file 'BV1uaZpYYEdE.json' already exists.
#
# Checking: BV1vK411B7Ze.pdf
#   Processing: BV1vK411B7Ze.pdf
#     Uploading 'BV1vK411B7Ze.pdf'...
#     Upload successful: files/f13zfil09z1k
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1vK411B7Ze.json'
#     Deleting uploaded file 'files/f13zfil09z1k' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 31 files
# Skipped (already exist): 8 files
# Errors encountered: 2 files
#
# Checking: BV1cM411N7eS.pdf
#   Processing: BV1cM411N7eS.pdf
#     Uploading 'BV1cM411N7eS.pdf'...
#     Upload successful: files/3z9zelm6vx2a
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1cM411N7eS.json'
#     Deleting uploaded file 'files/3z9zelm6vx2a' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 32 files
# Skipped (already exist): 8 files
# Errors encountered: 2 files
#
# Checking: BV1fQQ7YQEWJ.pdf
#   Processing: BV1fQQ7YQEWJ.pdf
#     Uploading 'BV1fQQ7YQEWJ.pdf'...
#     Upload successful: files/glaemwz6uzoh
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1fQQ7YQEWJ.json'
#     Deleting uploaded file 'files/glaemwz6uzoh' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 33 files
# Skipped (already exist): 8 files
# Errors encountered: 2 files
#
# Checking: BV1RdZnYMErF.pdf
#   Processing: BV1RdZnYMErF.pdf
#     Uploading 'BV1RdZnYMErF.pdf'...
#     Upload successful: files/xgsvmiy2uu0e
#     Generating descriptions and summary...
#     Parsing response...
#   ERROR: Failed to parse JSON response for 'BV1RdZnYMErF.pdf'. Skipping.
#     Error details: Expecting property name enclosed in double quotes: line 1150 column 10 (char 24270)
#     Received text: {
#   "video": "BV1RdZnYMErF",
#   "descriptions": [
#     {
#       "image0": [
#         {
#           "content": "黑客那么厉害",
#           "type": "中文文字",
#           "position": "最下方中间"
#         },
#         {
#           "content": "黑客壹笑",
#           "type": "中文文字",
#           "position": "左上角"
#         },
#         {
#           "content": "bilibili",
#           "type": "英文文字",
#           "position": "左上角"
#         },
#         {
#           "content": "vebx, 1 file descriptor (sys_value_true 0X9",
#           "type": "英文文字",
#    ...
#     Attempting to delete uploaded file 'files/xgsvmiy2uu0e' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 33 files
# Skipped (already exist): 8 files
# Errors encountered: 3 files
#
# Checking: BV1TUFreHEsB.pdf
#   Processing: BV1TUFreHEsB.pdf
#     Uploading 'BV1TUFreHEsB.pdf'...
#     Upload successful: files/nq63k36zr176
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1TUFreHEsB.json'
#     Deleting uploaded file 'files/nq63k36zr176' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 34 files
# Skipped (already exist): 8 files
# Errors encountered: 3 files
#
# Checking: BV1Rj411j7ro.pdf
#   Processing: BV1Rj411j7ro.pdf
#     Uploading 'BV1Rj411j7ro.pdf'...
#     Upload successful: files/gvnmaw4t6ro7
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1Rj411j7ro.json'
#     Deleting uploaded file 'files/gvnmaw4t6ro7' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 35 files
# Skipped (already exist): 8 files
# Errors encountered: 3 files
#
# Checking: BV1Hb421772G.pdf
#   Processing: BV1Hb421772G.pdf
#     Uploading 'BV1Hb421772G.pdf'...
#     Upload successful: files/cuncmr2aqmwi
#     Generating descriptions and summary...
#     Parsing response...
#   ERROR: An unexpected error occurred while processing 'BV1Hb421772G.pdf': ("Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 3. The candidate's safety_ratings are: [category: HARM_CATEGORY_HATE_SPEECH\nprobability: MEDIUM\nblocked: true\n, category: HARM_CATEGORY_DANGEROUS_CONTENT\nprobability: NEGLIGIBLE\n, category: HARM_CATEGORY_HARASSMENT\nprobability: MEDIUM\nblocked: true\n, category: HARM_CATEGORY_SEXUALLY_EXPLICIT\nprobability: NEGLIGIBLE\n].", [category: HARM_CATEGORY_HATE_SPEECH
# probability: MEDIUM
# blocked: true
# , category: HARM_CATEGORY_DANGEROUS_CONTENT
# probability: NEGLIGIBLE
# , category: HARM_CATEGORY_HARASSMENT
# probability: MEDIUM
# blocked: true
# , category: HARM_CATEGORY_SEXUALLY_EXPLICIT
# probability: NEGLIGIBLE
# ])
#     Attempting to delete potentially uploaded file 'files/cuncmr2aqmwi' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 35 files
# Skipped (already exist): 8 files
# Errors encountered: 4 files
#
# Checking: BV1MU9PYNEoM.pdf
#   Processing: BV1MU9PYNEoM.pdf
#     Uploading 'BV1MU9PYNEoM.pdf'...
#     Upload successful: files/zzdjk9qu7ei7
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1MU9PYNEoM.json'
#     Deleting uploaded file 'files/zzdjk9qu7ei7' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 36 files
# Skipped (already exist): 8 files
# Errors encountered: 4 files
#
# Checking: BV1ZXZnYgEG9.pdf
#   Processing: BV1ZXZnYgEG9.pdf
#     Uploading 'BV1ZXZnYgEG9.pdf'...
#     Upload successful: files/7mioljeyfpt7
#     Generating descriptions and summary...
#     Parsing response...
#   ERROR: An unexpected error occurred while processing 'BV1ZXZnYgEG9.pdf': ("Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 3. The candidate's safety_ratings are: [category: HARM_CATEGORY_HATE_SPEECH\nprobability: NEGLIGIBLE\n, category: HARM_CATEGORY_DANGEROUS_CONTENT\nprobability: MEDIUM\nblocked: true\n, category: HARM_CATEGORY_HARASSMENT\nprobability: NEGLIGIBLE\n, category: HARM_CATEGORY_SEXUALLY_EXPLICIT\nprobability: NEGLIGIBLE\n].", [category: HARM_CATEGORY_HATE_SPEECH
# probability: NEGLIGIBLE
# , category: HARM_CATEGORY_DANGEROUS_CONTENT
# probability: MEDIUM
# blocked: true
# , category: HARM_CATEGORY_HARASSMENT
# probability: NEGLIGIBLE
# , category: HARM_CATEGORY_SEXUALLY_EXPLICIT
# probability: NEGLIGIBLE
# ])
#     Attempting to delete potentially uploaded file 'files/7mioljeyfpt7' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 36 files
# Skipped (already exist): 8 files
# Errors encountered: 5 files
#
# Checking: BV1HPp3eJEmH.pdf
#   Skipping: Output file 'BV1HPp3eJEmH.json' already exists.
#
# Checking: BV1zu4m1u7bF.pdf
#   Skipping: Output file 'BV1zu4m1u7bF.json' already exists.
#
# Checking: BV1EY4y1G7gJ.pdf
#   Processing: BV1EY4y1G7gJ.pdf
#     Uploading 'BV1EY4y1G7gJ.pdf'...
#     Upload successful: files/uzmy12qelnfc
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1EY4y1G7gJ.json'
#     Deleting uploaded file 'files/uzmy12qelnfc' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 37 files
# Skipped (already exist): 10 files
# Errors encountered: 5 files
#
# Checking: BV1WhZzYMEUj.pdf
#   Processing: BV1WhZzYMEUj.pdf
#     Uploading 'BV1WhZzYMEUj.pdf'...
#     Upload successful: files/mkm9pizfb67f
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1WhZzYMEUj.json'
#     Deleting uploaded file 'files/mkm9pizfb67f' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 38 files
# Skipped (already exist): 10 files
# Errors encountered: 5 files
#
# Checking: BV1nWosYXE9g.pdf
#   Processing: BV1nWosYXE9g.pdf
#     Uploading 'BV1nWosYXE9g.pdf'...
#     Upload successful: files/kzsd0yibhn4y
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1nWosYXE9g.json'
#     Deleting uploaded file 'files/kzsd0yibhn4y' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 39 files
# Skipped (already exist): 10 files
# Errors encountered: 5 files
#
# Checking: BV1Dw4m1i7kn.pdf
#   Processing: BV1Dw4m1i7kn.pdf
#     Uploading 'BV1Dw4m1i7kn.pdf'...
#     Upload successful: files/qtkjw7upknq1
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1Dw4m1i7kn.json'
#     Deleting uploaded file 'files/qtkjw7upknq1' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 40 files
# Skipped (already exist): 10 files
# Errors encountered: 5 files
#
# Checking: BV12PS8YxEMQ.pdf
#   Skipping: Output file 'BV12PS8YxEMQ.json' already exists.
#
# Checking: BV1JEznYfE5i.pdf
#   Processing: BV1JEznYfE5i.pdf
#     Uploading 'BV1JEznYfE5i.pdf'...
#     Upload successful: files/lf2wnx8i97fr
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1JEznYfE5i.json'
#     Deleting uploaded file 'files/lf2wnx8i97fr' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 41 files
# Skipped (already exist): 11 files
# Errors encountered: 5 files
#
# Checking: BV1HDQ6YQEut.pdf
#   Skipping: Output file 'BV1HDQ6YQEut.json' already exists.
#
# Checking: BV1KY4y1R7gx.pdf
#   Processing: BV1KY4y1R7gx.pdf
#     Uploading 'BV1KY4y1R7gx.pdf'...
#     Upload successful: files/b3hvdgd2py08
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1KY4y1R7gx.json'
#     Deleting uploaded file 'files/b3hvdgd2py08' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 42 files
# Skipped (already exist): 12 files
# Errors encountered: 5 files
#
# Checking: BV1LFZGYyEZ4.pdf
#   Processing: BV1LFZGYyEZ4.pdf
#     Uploading 'BV1LFZGYyEZ4.pdf'...
#     Upload successful: files/ypqt1z6tg7u9
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1LFZGYyEZ4.json'
#     Deleting uploaded file 'files/ypqt1z6tg7u9' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 43 files
# Skipped (already exist): 12 files
# Errors encountered: 5 files
#
# Checking: BV1ptQ8YoEEa.pdf
#   Skipping: Output file 'BV1ptQ8YoEEa.json' already exists.
#
# Checking: BV1UCZ7YSEH2.pdf
#   Processing: BV1UCZ7YSEH2.pdf
#     Uploading 'BV1UCZ7YSEH2.pdf'...
#     Upload successful: files/znl4dsqks5ek
#     Generating descriptions and summary...
#     Parsing response...
#   ERROR: Failed to parse JSON response for 'BV1UCZ7YSEH2.pdf'. Skipping.
#     Error details: Expecting value: line 1236 column 22 (char 24671)
#     Received text: {
#   "video": "BV1UCZ7YSEH2",
#   "descriptions": [
#     {
#       "image0": [
#         {
#           "content": "绝境交给木白",
#           "type": "中文文字",
#           "position": "左上角"
#         },
#         {
#           "content": "69",
#           "type": "数字",
#           "position": "左下角"
#         },
#         {
#           "content": "回城",
#           "type": "中文文字",
#           "position": "最下方中间"
#         },
#         {
#           "content": "50",
#           "type": "数字",
#           "position": "最下方中间"
#         },
#         {
#      ...
#     Attempting to delete uploaded file 'files/znl4dsqks5ek' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 43 files
# Skipped (already exist): 13 files
# Errors encountered: 6 files
#
# Checking: BV1WW2hYDESo.pdf
#   Processing: BV1WW2hYDESo.pdf
#     Uploading 'BV1WW2hYDESo.pdf'...
#     Upload successful: files/q5ozb3lbrxua
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1WW2hYDESo.json'
#     Deleting uploaded file 'files/q5ozb3lbrxua' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 44 files
# Skipped (already exist): 13 files
# Errors encountered: 6 files
#
# Checking: BV1dVZCYKERy.pdf
#   Processing: BV1dVZCYKERy.pdf
#     Uploading 'BV1dVZCYKERy.pdf'...
#     Upload successful: files/hvgwisaw4x1g
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1dVZCYKERy.json'
#     Deleting uploaded file 'files/hvgwisaw4x1g' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 45 files
# Skipped (already exist): 13 files
# Errors encountered: 6 files
#
# Checking: BV1934y1F7kj.pdf
#   Processing: BV1934y1F7kj.pdf
#     Uploading 'BV1934y1F7kj.pdf'...
#     Upload successful: files/iahml3hidxt6
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1934y1F7kj.json'
#     Deleting uploaded file 'files/iahml3hidxt6' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 46 files
# Skipped (already exist): 13 files
# Errors encountered: 6 files
#
# Checking: BV19aZPYSEFg.pdf
#   Processing: BV19aZPYSEFg.pdf
#     Uploading 'BV19aZPYSEFg.pdf'...
#     Upload successful: files/3nc74vsso80l
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV19aZPYSEFg.json'
#     Deleting uploaded file 'files/3nc74vsso80l' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 47 files
# Skipped (already exist): 13 files
# Errors encountered: 6 files
#
# Checking: BV1UCZbYJE9K.pdf
#   Processing: BV1UCZbYJE9K.pdf
#     Uploading 'BV1UCZbYJE9K.pdf'...
#     Upload successful: files/y8t5whkm88zs
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1UCZbYJE9K.json'
#     Deleting uploaded file 'files/y8t5whkm88zs' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 48 files
# Skipped (already exist): 13 files
# Errors encountered: 6 files
#
# Checking: BV1mcZ4YgEXH.pdf
#   Processing: BV1mcZ4YgEXH.pdf
#     Uploading 'BV1mcZ4YgEXH.pdf'...
#     Upload successful: files/g662eynrj7ju
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1mcZ4YgEXH.json'
#     Deleting uploaded file 'files/g662eynrj7ju' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 49 files
# Skipped (already exist): 13 files
# Errors encountered: 6 files
#
# Checking: BV1YqZbYWEK1.pdf
#   Processing: BV1YqZbYWEK1.pdf
#     Uploading 'BV1YqZbYWEK1.pdf'...
#     Upload successful: files/ftrwh8jdwui8
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1YqZbYWEK1.json'
#     Deleting uploaded file 'files/ftrwh8jdwui8' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 50 files
# Skipped (already exist): 13 files
# Errors encountered: 6 files
#
# Checking: BV1ARZ4YPEj5.pdf
#   Processing: BV1ARZ4YPEj5.pdf
#     Uploading 'BV1ARZ4YPEj5.pdf'...
#     Upload successful: files/z6da7h81loyq
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1ARZ4YPEj5.json'
#     Deleting uploaded file 'files/z6da7h81loyq' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 51 files
# Skipped (already exist): 13 files
# Errors encountered: 6 files
#
# Checking: BV19UQCYSEZK.pdf
#   Processing: BV19UQCYSEZK.pdf
#     Uploading 'BV19UQCYSEZK.pdf'...
#     Upload successful: files/imxouzx80oh0
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV19UQCYSEZK.json'
#     Deleting uploaded file 'files/imxouzx80oh0' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 52 files
# Skipped (already exist): 13 files
# Errors encountered: 6 files
#
# Checking: BV1HC411Y7HH.pdf
#   Skipping: Output file 'BV1HC411Y7HH.json' already exists.
#
# Checking: BV1DHayeEE6y.pdf
#   Processing: BV1DHayeEE6y.pdf
#     Uploading 'BV1DHayeEE6y.pdf'...
#     Upload successful: files/8wqb3ejp8zjh
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1DHayeEE6y.json'
#     Deleting uploaded file 'files/8wqb3ejp8zjh' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 53 files
# Skipped (already exist): 14 files
# Errors encountered: 6 files
#
# Checking: BV1S7BiYDEuT.pdf
#   Processing: BV1S7BiYDEuT.pdf
#     Uploading 'BV1S7BiYDEuT.pdf'...
#     Upload successful: files/8tslzwek2g2g
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1S7BiYDEuT.json'
#     Deleting uploaded file 'files/8tslzwek2g2g' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 54 files
# Skipped (already exist): 14 files
# Errors encountered: 6 files
#
# Checking: BV1zXotY8EUL.pdf
#   Skipping: Output file 'BV1zXotY8EUL.json' already exists.
#
# Checking: BV1FVXAYjEyz.pdf
#   Processing: BV1FVXAYjEyz.pdf
#     Uploading 'BV1FVXAYjEyz.pdf'...
#     Upload successful: files/e75bc48r16lc
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1FVXAYjEyz.json'
#     Deleting uploaded file 'files/e75bc48r16lc' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 55 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV1SUfUY6EA7.pdf
#   Processing: BV1SUfUY6EA7.pdf
#     Uploading 'BV1SUfUY6EA7.pdf'...
#     Upload successful: files/3y96ma7pjtv4
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1SUfUY6EA7.json'
#     Deleting uploaded file 'files/3y96ma7pjtv4' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 56 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV1ofQJYREmd.pdf
#   Processing: BV1ofQJYREmd.pdf
#     Uploading 'BV1ofQJYREmd.pdf'...
#     Upload successful: files/7otx5fias2pz
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1ofQJYREmd.json'
#     Deleting uploaded file 'files/7otx5fias2pz' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 57 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV1YjSvYXEZz.pdf
#   Processing: BV1YjSvYXEZz.pdf
#     Uploading 'BV1YjSvYXEZz.pdf'...
#     Upload successful: files/2hgxht4fcx6h
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1YjSvYXEZz.json'
#     Deleting uploaded file 'files/2hgxht4fcx6h' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 58 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV1GS4y127RQ.pdf
#   Processing: BV1GS4y127RQ.pdf
#     Uploading 'BV1GS4y127RQ.pdf'...
#     Upload successful: files/b6asb2i8j0vr
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1GS4y127RQ.json'
#     Deleting uploaded file 'files/b6asb2i8j0vr' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 59 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV1TG41157Ww.pdf
#   Processing: BV1TG41157Ww.pdf
#     Uploading 'BV1TG41157Ww.pdf'...
#     Upload successful: files/nms316bt1wyw
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1TG41157Ww.json'
#     Deleting uploaded file 'files/nms316bt1wyw' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 60 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV1jbZbYfE1m.pdf
#   Processing: BV1jbZbYfE1m.pdf
#     Uploading 'BV1jbZbYfE1m.pdf'...
#     Upload successful: files/jo4xeyz16i4x
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1jbZbYfE1m.json'
#     Deleting uploaded file 'files/jo4xeyz16i4x' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 61 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV1LtZ4YQEbt.pdf
#   Processing: BV1LtZ4YQEbt.pdf
#     Uploading 'BV1LtZ4YQEbt.pdf'...
#     Upload successful: files/ib5sjdcx4htz
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1LtZ4YQEbt.json'
#     Deleting uploaded file 'files/ib5sjdcx4htz' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 62 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV1rSQ6YpEDb.pdf
#   Processing: BV1rSQ6YpEDb.pdf
#     Uploading 'BV1rSQ6YpEDb.pdf'...
#     Upload successful: files/3g86rraqla72
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1rSQ6YpEDb.json'
#     Deleting uploaded file 'files/3g86rraqla72' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 63 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV1eHaxeiERC.pdf
#   Processing: BV1eHaxeiERC.pdf
#     Uploading 'BV1eHaxeiERC.pdf'...
#     Upload successful: files/91e5tynqb1uo
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1eHaxeiERC.json'
#     Deleting uploaded file 'files/91e5tynqb1uo' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 64 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV1mFPEe8EP2.pdf
#   Processing: BV1mFPEe8EP2.pdf
#     Uploading 'BV1mFPEe8EP2.pdf'...
#     Upload successful: files/dc4j2qy9r0z0
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1mFPEe8EP2.json'
#     Deleting uploaded file 'files/dc4j2qy9r0z0' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 65 files
# Skipped (already exist): 15 files
# Errors encountered: 6 files
#
# Checking: BV16K411x7xu.pdf
#   Skipping: Output file 'BV16K411x7xu.json' already exists.
#
# Checking: BV1C7fZYXEF8.pdf
#   Processing: BV1C7fZYXEF8.pdf
#     Uploading 'BV1C7fZYXEF8.pdf'...
#     Upload successful: files/kueh01s3geed
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1C7fZYXEF8.json'
#     Deleting uploaded file 'files/kueh01s3geed' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 66 files
# Skipped (already exist): 16 files
# Errors encountered: 6 files
#
# Checking: BV1nHZbYeEC3.pdf
#   Skipping: Output file 'BV1nHZbYeEC3.json' already exists.
#
# Checking: BV1xi421a7dB.pdf
#   Processing: BV1xi421a7dB.pdf
#     Uploading 'BV1xi421a7dB.pdf'...
#     Upload successful: files/shm9xb1jogw9
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1xi421a7dB.json'
#     Deleting uploaded file 'files/shm9xb1jogw9' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 67 files
# Skipped (already exist): 17 files
# Errors encountered: 6 files
#
# Checking: BV1fM4y167jW.pdf
#   Processing: BV1fM4y167jW.pdf
#     Uploading 'BV1fM4y167jW.pdf'...
#     Upload successful: files/ks1do7p4haoe
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1fM4y167jW.json'
#     Deleting uploaded file 'files/ks1do7p4haoe' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 68 files
# Skipped (already exist): 17 files
# Errors encountered: 6 files
#
# Checking: BV1qHZ4YdEGu.pdf
#   Skipping: Output file 'BV1qHZ4YdEGu.json' already exists.
#
# Checking: BV1xd1CYWENp.pdf
#   Skipping: Output file 'BV1xd1CYWENp.json' already exists.
#
# Checking: BV1XwZHYPEVP.pdf
#   Processing: BV1XwZHYPEVP.pdf
#     Uploading 'BV1XwZHYPEVP.pdf'...
#     Upload successful: files/r4owddrqh3he
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1XwZHYPEVP.json'
#     Deleting uploaded file 'files/r4owddrqh3he' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 69 files
# Skipped (already exist): 19 files
# Errors encountered: 6 files
#
# Checking: BV1cUwSe3EtB.pdf
#   Processing: BV1cUwSe3EtB.pdf
#     Uploading 'BV1cUwSe3EtB.pdf'...
#     Upload successful: files/lzriyzcqss1h
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1cUwSe3EtB.json'
#     Deleting uploaded file 'files/lzriyzcqss1h' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 70 files
# Skipped (already exist): 19 files
# Errors encountered: 6 files
#
# Checking: BV1Qs4y1R7yo.pdf
#   Processing: BV1Qs4y1R7yo.pdf
#     Uploading 'BV1Qs4y1R7yo.pdf'...
#     Upload successful: files/xkyllgkk3xtq
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1Qs4y1R7yo.json'
#     Deleting uploaded file 'files/xkyllgkk3xtq' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 71 files
# Skipped (already exist): 19 files
# Errors encountered: 6 files
#
# Checking: BV1BeZHYGEtn.pdf
#   Processing: BV1BeZHYGEtn.pdf
#     Uploading 'BV1BeZHYGEtn.pdf'...
#     Upload successful: files/p4kwls2g7fba
#     Generating descriptions and summary...
#     Parsing response...
#   ERROR: Failed to parse JSON response for 'BV1BeZHYGEtn.pdf'. Skipping.
#     Error details: Unterminated string starting at: line 988 column 11 (char 22192)
#     Received text: {
#   "video": "BV1BeZHYGEtn",
#   "descriptions": [
#     {
#       "image0": [
#         {
#           "content": "Eliza",
#           "type": "英文文字",
#           "position": "左上角"
#         },
#         {
#           "content": "伊丽莎,你高大的软蛋大学室",
#           "type": "中文文字",
#           "position": "左上角"
#         },
#         {
#           "content": "Aisha",
#           "type": "英文文字",
#           "position": "正中央"
#         },
#         {
#           "content": "市场上的奴隶女,你会买吗?",
#           "type": "中文文字",
#           "position": "正中央"
#   ...
#     Attempting to delete uploaded file 'files/p4kwls2g7fba' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 71 files
# Skipped (already exist): 19 files
# Errors encountered: 7 files
#
# Checking: BV12sPYezErS.pdf
#   Skipping: Output file 'BV12sPYezErS.json' already exists.
#
# Checking: BV1tqZpYFEY9.pdf
#   Processing: BV1tqZpYFEY9.pdf
#     Uploading 'BV1tqZpYFEY9.pdf'...
#     Upload successful: files/cy154l2a2nyl
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1tqZpYFEY9.json'
#     Deleting uploaded file 'files/cy154l2a2nyl' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 72 files
# Skipped (already exist): 20 files
# Errors encountered: 7 files
#
# Checking: BV1kXXNY4E9M.pdf
#   Processing: BV1kXXNY4E9M.pdf
#     Uploading 'BV1kXXNY4E9M.pdf'...
#     Upload successful: files/n4f13vb3j94s
#     Generating descriptions and summary...
#     Parsing response...
#     Success: Saved results to 'BV1kXXNY4E9M.json'
#     Deleting uploaded file 'files/n4f13vb3j94s' from API storage...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 73 files
# Skipped (already exist): 20 files
# Errors encountered: 7 files
#
# Checking: BV1NDZbYyEPt.pdf
#   Processing: BV1NDZbYyEPt.pdf
# ...
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
#     Attempting to delete potentially uploaded file 'files/zdbsvcnqokgg' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3053 files
# Errors encountered: 459 files
#
# Checking: BV1D4Pqe9EN1.pdf
#   Skipping: Output file 'BV1D4Pqe9EN1.json' already exists.
#
# Checking: BV1Wo4y1M7dx.pdf
#   Skipping: Output file 'BV1Wo4y1M7dx.json' already exists.
#
# Checking: BV15DX7Y7EXY.pdf
#   Skipping: Output file 'BV15DX7Y7EXY.json' already exists.
#
# Checking: BV1sgZ4YPEjp.pdf
#   Skipping: Output file 'BV1sgZ4YPEjp.json' already exists.
#
# Checking: BV1Rh4y1D71j.pdf
#   Skipping: Output file 'BV1Rh4y1D71j.json' already exists.
#
# Checking: BV15rBuYnEtB.pdf
#   Skipping: Output file 'BV15rBuYnEtB.json' already exists.
#
# Checking: BV1NY411d7J6.pdf
#   Skipping: Output file 'BV1NY411d7J6.json' already exists.
#
# Checking: BV1ezZJYcENs.pdf
#   Skipping: Output file 'BV1ezZJYcENs.json' already exists.
#
# Checking: BV1eYkXYJEWQ.pdf
#   Skipping: Output file 'BV1eYkXYJEWQ.json' already exists.
#
# Checking: BV1zNffYDEP2.pdf
#   Skipping: Output file 'BV1zNffYDEP2.json' already exists.
#
# Checking: BV1vSZtYxEAV.pdf
#   Skipping: Output file 'BV1vSZtYxEAV.json' already exists.
#
# Checking: BV1kh411Z7YV.pdf
#   Skipping: Output file 'BV1kh411Z7YV.json' already exists.
#
# Checking: BV1CuxpexEd1.pdf
#   Skipping: Output file 'BV1CuxpexEd1.json' already exists.
#
# Checking: BV1ipeJebEeC.pdf
#   Skipping: Output file 'BV1ipeJebEeC.json' already exists.
#
# Checking: BV1zB4y1b7xQ.pdf
#   Skipping: Output file 'BV1zB4y1b7xQ.json' already exists.
#
# Checking: BV1k24y1N74M.pdf
#   Skipping: Output file 'BV1k24y1N74M.json' already exists.
#
# Checking: BV1Pz4y1T7CB.pdf
#   Skipping: Output file 'BV1Pz4y1T7CB.json' already exists.
#
# Checking: BV1P6FYeREw9.pdf
#   Processing: BV1P6FYeREw9.pdf
#     Uploading 'BV1P6FYeREw9.pdf'...
#     Upload successful: files/cr9mnmdfjxff
#     Generating descriptions and summary...
#   ERROR: An unexpected error occurred while processing 'BV1P6FYeREw9.pdf': 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 59
# }
# ]
#     Attempting to delete potentially uploaded file 'files/cr9mnmdfjxff' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3070 files
# Errors encountered: 460 files
#
# Checking: BV1Ci4y1W7UB.pdf
#   Skipping: Output file 'BV1Ci4y1W7UB.json' already exists.
#
# Checking: BV124ZqYAEG8.pdf
#   Skipping: Output file 'BV124ZqYAEG8.json' already exists.
#
# Checking: BV1YnZCYhEuQ.pdf
#   Skipping: Output file 'BV1YnZCYhEuQ.json' already exists.
#
# Checking: BV1FFZ8YBEZ8.pdf
#   Skipping: Output file 'BV1FFZ8YBEZ8.json' already exists.
#
# Checking: BV1cq4y1G7pV.pdf
#   Skipping: Output file 'BV1cq4y1G7pV.json' already exists.
#
# Checking: BV1qU411d7w6.pdf
#   Skipping: Output file 'BV1qU411d7w6.json' already exists.
#
# Checking: BV1ow411y7Zt.pdf
#   Skipping: Output file 'BV1ow411y7Zt.json' already exists.
#
# Checking: BV1yJZHYQEHT.pdf
#   Skipping: Output file 'BV1yJZHYQEHT.json' already exists.
#
# Checking: BV1nHZbYeE3Y.pdf
#   Skipping: Output file 'BV1nHZbYeE3Y.json' already exists.
#
# Checking: BV14LBCYKELQ.pdf
#   Skipping: Output file 'BV14LBCYKELQ.json' already exists.
#
# Checking: BV1hSZHYwEYh.pdf
#   Processing: BV1hSZHYwEYh.pdf
#     Uploading 'BV1hSZHYwEYh.pdf'...
#     Upload successful: files/eys3vltxjzqz
#     Generating descriptions and summary...
#   ERROR: An unexpected error occurred while processing 'BV1hSZHYwEYh.pdf': 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
#     Attempting to delete potentially uploaded file 'files/eys3vltxjzqz' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3080 files
# Errors encountered: 461 files
#
# Checking: BV1kSZVYFEoA.pdf
#   Skipping: Output file 'BV1kSZVYFEoA.json' already exists.
#
# Checking: BV1HRZ4YPEKw.pdf
#   Skipping: Output file 'BV1HRZ4YPEKw.json' already exists.
#
# Checking: BV19bN7eyEkY.pdf
#   Skipping: Output file 'BV19bN7eyEkY.json' already exists.
#
# Checking: BV1SB4y1i7TY.pdf
#   Processing: BV1SB4y1i7TY.pdf
#     Uploading 'BV1SB4y1i7TY.pdf'...
#     Upload successful: files/ksltzr2dvykp
#     Generating descriptions and summary...
#   ERROR: An unexpected error occurred while processing 'BV1SB4y1i7TY.pdf': 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
#     Attempting to delete potentially uploaded file 'files/ksltzr2dvykp' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3083 files
# Errors encountered: 462 files
#
# Checking: BV1Hb42187yc.pdf
#   Skipping: Output file 'BV1Hb42187yc.json' already exists.
#
# Checking: BV1or42187Pe.pdf
#   Skipping: Output file 'BV1or42187Pe.json' already exists.
#
# Checking: BV18HvMeWE2B.pdf
#   Skipping: Output file 'BV18HvMeWE2B.json' already exists.
#
# Checking: BV1GAoBYyEbi.pdf
#   Skipping: Output file 'BV1GAoBYyEbi.json' already exists.
#
# Checking: BV1DW4y1D7ex.pdf
#   Skipping: Output file 'BV1DW4y1D7ex.json' already exists.
#
# Checking: BV1TtoyYQEAC.pdf
#   Skipping: Output file 'BV1TtoyYQEAC.json' already exists.
#
# Checking: BV1j6ZcYmEhZ.pdf
#   Skipping: Output file 'BV1j6ZcYmEhZ.json' already exists.
#
# Checking: BV1MSzmYpEFJ.pdf
#   Skipping: Output file 'BV1MSzmYpEFJ.json' already exists.
#
# Checking: BV17TZEYPEKW.pdf
#   Skipping: Output file 'BV17TZEYPEKW.json' already exists.
#
# Checking: BV1Ua411W7b6.pdf
#   Skipping: Output file 'BV1Ua411W7b6.json' already exists.
#
# Checking: BV1hGRjY3Esi.pdf
#   Skipping: Output file 'BV1hGRjY3Esi.json' already exists.
#
# Checking: BV1tkoXY5Ean.pdf
#   Skipping: Output file 'BV1tkoXY5Ean.json' already exists.
#
# Checking: BV1X8oDYyEMW.pdf
#   Skipping: Output file 'BV1X8oDYyEMW.json' already exists.
#
# Checking: BV1G42rY8EEb.pdf
#   Skipping: Output file 'BV1G42rY8EEb.json' already exists.
#
# Checking: BV1tBX5YZE9y.pdf
#   Skipping: Output file 'BV1tBX5YZE9y.json' already exists.
#
# Checking: BV12H4y1G7bd.pdf
#   Skipping: Output file 'BV12H4y1G7bd.json' already exists.
#
# Checking: BV1ZjZsYHESQ.pdf
#   Processing: BV1ZjZsYHESQ.pdf
#     Uploading 'BV1ZjZsYHESQ.pdf'...
#     Upload successful: files/xau5k2ipzff4
#     Generating descriptions and summary...
#   ERROR: An unexpected error occurred while processing 'BV1ZjZsYHESQ.pdf': 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
#     Attempting to delete potentially uploaded file 'files/xau5k2ipzff4' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3099 files
# Errors encountered: 463 files
#
# Checking: BV15qooYPEHH.pdf
#   Skipping: Output file 'BV15qooYPEHH.json' already exists.
#
# Checking: BV1EwZtYbEp3.pdf
#   Skipping: Output file 'BV1EwZtYbEp3.json' already exists.
#
# Checking: BV1fC4y1v7LM.pdf
#   Processing: BV1fC4y1v7LM.pdf
#     Uploading 'BV1fC4y1v7LM.pdf'...
#     Upload successful: files/hgiq9nbcvkrc
#     Generating descriptions and summary...
#   ERROR: An unexpected error occurred while processing 'BV1fC4y1v7LM.pdf': 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
#     Attempting to delete potentially uploaded file 'files/hgiq9nbcvkrc' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3101 files
# Errors encountered: 464 files
#
# Checking: BV1zNovY1EVR.pdf
#   Skipping: Output file 'BV1zNovY1EVR.json' already exists.
#
# Checking: BV1Ft421Y78D.pdf
#   Skipping: Output file 'BV1Ft421Y78D.json' already exists.
#
# Checking: BV1BH4y1c7Zy.pdf
#   Skipping: Output file 'BV1BH4y1c7Zy.json' already exists.
#
# Checking: BV192P7euEAE.pdf
#   Skipping: Output file 'BV192P7euEAE.json' already exists.
#
# Checking: BV1Ji4y197EJ.pdf
#   Processing: BV1Ji4y197EJ.pdf
#     Uploading 'BV1Ji4y197EJ.pdf'...
#     Upload successful: files/7veew66ym2ua
#     Generating descriptions and summary...
#   ERROR: An unexpected error occurred while processing 'BV1Ji4y197EJ.pdf': 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#     Attempting to delete potentially uploaded file 'files/7veew66ym2ua' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3105 files
# Errors encountered: 465 files
#
# Checking: BV15zNGeYEfj.pdf
#   Skipping: Output file 'BV15zNGeYEfj.json' already exists.
#
# Checking: BV1uCZbYJEAU.pdf
#   Skipping: Output file 'BV1uCZbYJEAU.json' already exists.
#
# Checking: BV151ZvYGERt.pdf
#   Skipping: Output file 'BV151ZvYGERt.json' already exists.
#
# Checking: BV1Gf4y187Vz.pdf
#   Skipping: Output file 'BV1Gf4y187Vz.json' already exists.
#
# Checking: BV1rtSKYQEZQ.pdf
#   Skipping: Output file 'BV1rtSKYQEZQ.json' already exists.
#
# Checking: BV1Tw411B7zU.pdf
#   Skipping: Output file 'BV1Tw411B7zU.json' already exists.
#
# Checking: BV1sL411N7yV.pdf
#   Skipping: Output file 'BV1sL411N7yV.json' already exists.
#
# Checking: BV1CEZJYyE81.pdf
#   Skipping: Output file 'BV1CEZJYyE81.json' already exists.
#
# Checking: BV1eM4m1y74J.pdf
#   Skipping: Output file 'BV1eM4m1y74J.json' already exists.
#
# Checking: BV1v2XfYcEP3.pdf
#   Skipping: Output file 'BV1v2XfYcEP3.json' already exists.
#
# Checking: BV1ej42197aH.pdf
#   Skipping: Output file 'BV1ej42197aH.json' already exists.
#
# Checking: BV1UtC8YEEh3.pdf
#   Processing: BV1UtC8YEEh3.pdf
#     Uploading 'BV1UtC8YEEh3.pdf'...
#     Upload successful: files/s2k9a27sz3k0
#     Generating descriptions and summary...
#   ERROR: An unexpected error occurred while processing 'BV1UtC8YEEh3.pdf': 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
#     Attempting to delete potentially uploaded file 'files/s2k9a27sz3k0' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3116 files
# Errors encountered: 466 files
#
# Checking: BV1UyHpeoEGT.pdf
#   Processing: BV1UyHpeoEGT.pdf
#     Uploading 'BV1UyHpeoEGT.pdf'...
#     Upload successful: files/7hfl6uoxvc13
#     Generating descriptions and summary...
#   ERROR: An unexpected error occurred while processing 'BV1UyHpeoEGT.pdf': 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
#     Attempting to delete potentially uploaded file 'files/7hfl6uoxvc13' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3116 files
# Errors encountered: 467 files
#
# Checking: BV14DZJYXEPT.pdf
#   Skipping: Output file 'BV14DZJYXEPT.json' already exists.
#
# Checking: BV1pe4y1H7pD.pdf
#   Skipping: Output file 'BV1pe4y1H7pD.json' already exists.
#
# Checking: BV1b7XLYwESg.pdf
#   Skipping: Output file 'BV1b7XLYwESg.json' already exists.
#
# Checking: BV1uGoBYBEKW.pdf
#   Skipping: Output file 'BV1uGoBYBEKW.json' already exists.
#
# Checking: BV1rb411J7Zy.pdf
#   Skipping: Output file 'BV1rb411J7Zy.json' already exists.
#
# Checking: BV1U3qqYDE5Q.pdf
#   Skipping: Output file 'BV1U3qqYDE5Q.json' already exists.
#
# Checking: BV1EvpvejESB.pdf
#   Skipping: Output file 'BV1EvpvejESB.json' already exists.
#
# Checking: BV112zRYqEcM.pdf
#   Skipping: Output file 'BV112zRYqEcM.json' already exists.
#
# Checking: BV16c411F7WP.pdf
#   Skipping: Output file 'BV16c411F7WP.json' already exists.
#
# Checking: BV16H9mYkE4W.pdf
#   Skipping: Output file 'BV16H9mYkE4W.json' already exists.
#
# Checking: BV1qakFYgEgc.pdf
#   Skipping: Output file 'BV1qakFYgEgc.json' already exists.
#
# Checking: BV176PMepEJ3.pdf
#   Skipping: Output file 'BV176PMepEJ3.json' already exists.
#
# Checking: BV1WPZpYQE76.pdf
#   Processing: BV1WPZpYQE76.pdf
#     Uploading 'BV1WPZpYQE76.pdf'...
#     Upload successful: files/m0pyyqg35nlf
#     Generating descriptions and summary...
#   ERROR: An unexpected error occurred while processing 'BV1WPZpYQE76.pdf': 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
#     Attempting to delete potentially uploaded file 'files/m0pyyqg35nlf' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3128 files
# Errors encountered: 468 files
#
# Checking: BV1eC4y137yu.pdf
#   Processing: BV1eC4y137yu.pdf
#     Uploading 'BV1eC4y137yu.pdf'...
#     Upload successful: files/sv6prznr41xa
#     Generating descriptions and summary...
#   ERROR: An unexpected error occurred while processing 'BV1eC4y137yu.pdf': 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
#     Attempting to delete potentially uploaded file 'files/sv6prznr41xa' after error...
#     Uploaded file deleted successfully.
# ------------------------------
# Processing Complete.
# Successfully processed: 600 files
# Skipped (already exist): 3128 files
# Errors encountered: 469 files
#
# Checking: BV1eQq8YgEWS.pdf
#   Skipping: Output file 'BV1eQq8YgEWS.json' already exists.
#
# Checking: BV1pENgeuEbb.pdf
#   Skipping: Output file 'BV1pENgeuEbb.json' already exists.
